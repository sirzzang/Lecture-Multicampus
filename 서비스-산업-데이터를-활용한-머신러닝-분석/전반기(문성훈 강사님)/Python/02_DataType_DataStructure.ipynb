# %%
# Python Built-in Type
# Numeric(int(정수), float(실수), complex(복소수))
# Text Sequence : 문자열 (str)
# Bool : True, False (bool)
# 자료구조
# Sequence( list, tuple )
# Mapping ( dict )
# Set ( set )

# %%
# Numeric Data Type
# int (정수)
# float (실수)
# complex (복소수)

a = 123 # 정수(10진수)
b = 3.14159265358979 # 실수
c = 3.14E10  # 지수표현(실수)
d = 1 + 2j   # 복소수
e = 0o37     # 앞에 있는 0(숫자0), 
             # 뒤에있는 o(영문자)  => 8진수
f = 0xFF     # 16진수

print(type(a))   # a의 data type을 알려줘요!
print(type(b))
print(type(c))

div = 3 / 4   # 0.75(3.x 버전, 2.x버전 : 0) 
print(div)

result = 3 ** 4 # 지수표현
print(result)

result = 100 % 3 # 나머지 연산 
print(result)

result = 10 // 3 # 나눗셈의 몫
print(result)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>
# 0.75
# 81
# 1
# 3

# %%
# Text Sequence Type (str)
# 우리가 일반적으로 말하는 문자열

# 문자열 생성방법(4가지)
a = "Hello"   # "" 를 이용 (한줄짜리 문자열)
b = 'Hello'   # '' 를 이용 (한줄짜리 문자열)
# 여러줄짜리 문자열을 만들때 사용
c = """이것은 
소리없는
아우성"""
d = '''이것은 
소리없는
아우성'''
#print(c)

#############################

# 문자열 연산, Indexing, Slicing
first = "이것은"
last = "소리없는 아우성!!"
# 두 문자열을 연결
result = first + last  # 연산자 overloading
#print(result)
# 문자열의 곱
text = "python"
#print(text * 3)  # 문자열을 3번 연결하는거네요!

a = "this is a sample text!!. show me the money!"
# Indexing ( 0부터 시작 )
# print(a[0])  # t
# print(a[8])  # a
# print(a[-1]) # !   - 의미는 뒤부터 indexing
# slicing ( 일부분을 발췌 )
a = "this is a sample text!!. show me the money!"
#print(a[0:3])  # 시작은 inclusive, 
               # 마지막은 exclusive
#print(a[:4])   # 시작부분이 없으면 처음부터(0)
#print(a[4:])   # 마지막이 없으면 끝까지
#print(a[:])    # 문자열의 처음부터 끝까지

# in , not in 연산자 => 논리연산
a = "this is a Sample Text"

#print("this" in a)  # True ( TRUE X )
#print("this" not in a) # False
#print("sample" in a) # False
#print("sample" in a.lower()) # True

# 문자열 formatting
apple = 10;
#a = "사과가 10개 있어요!!"
#a = "사과가 " + str(apple) + "개 있어요!!"   
#print(a)
# 이렇게 할 수 있는데 너무 복잡스러워요!
#a = "사과가 %d개 있어요!!" %apple
#print(a)
#a = "사과 %d개, 바나나가 %d개 있어요!!" %(apple,5)
#print(a)
#a = "원주율은 %f입니다." %3.141592
#print(a)
#a = "이것은 소리없는 %10s!!" %"아우성"  # 오른쪽정렬
#a = "이것은 소리없는 %-10s!!" %"아우성"  # 왼쪽정렬
#print(a)

#a = "원주율은 %10.4f" %3.141592 # 5번짜리에서 반올림
#print(a)

## 문자열 함수
a = "cocacola"
# 문자열 길이
#result = len(a); print(result)
#result = a.count("co"); print(result)
#result = a.find("o"); print(result) # 찾은곳의 index
# a = ":"
# b = "abcd"
# result = a.join(b); print(result);

# a = ["이것은","소리없는","아우성"]
# b = " "
# result = b.join(a); 
# print(result);

a = " hoBBy " 
# print(a.upper()) # 대문자
# print(a.lower()) # 소문자
#print(a)
#print(a.strip()) # 앞과 뒤에 공백을 제거

#############################
# 출력양식을 설정할때 formatting 이용
# apple = 10
# a = "사과가 %d개 있어요!!" %apple
# print(a)
a = "사과를 {}개, 바나나 {}개 가지고 있어요!".format(6,10)
print(a)

# Numeric(정수, 실수), str
###################################################

# 우리 자료구조에 대해서 알아보아요!!
# Out:
# 사과를 6개, 바나나 10개 가지고 있어요!

# %%
## Sequence Type
## list
## 임의의 객체를 순차적으로 저장하는 자료구조
## 기호로는 [] (대괄호를 이용)
myList = list()  # 비어있는 list를 생성
myList = []      # list를 literal로 표현
myList = [1,2,3] # 3개의 값을 가지는 list를 생성
myList = [1,3.14,True,"아우성!!"] # 모든 데이터 타입을 다 저장
myList = [10,["Show","me","the","money"],3.14,True]
# List안에 또 다른 자료구조들을 넣을 수 있어요!
#print(myList[2])
#print(myList[1][3])
#print(myList[-1])
#print(myList[0:1])  # slicing결과는 원본자료구조와 동일
#print(myList[1][2:])

# list의 연산
a = [1,2,3]
b = [4,5,6]
#print(a+b)
#print(a*3)

# list의 indexing & slicing
a = [1,2,3]
#a[0] = 5    # 5, 2, 3
#a[1:] = []  # list slicing한 부분을 다른 리스트로 대체
#a[0:1] = [7,8,9]   # 7 ,8 ,9 ,2 , 3
#a[0] = [7,8,9]     # [[7,8,9],2,3]
#del a[1]
#print(a)

# list에 적용할 수 있는 함수
a = [1,2,3]
#a.append("Hello")
#a.append([4,5,6])  # list의 맨 마지막칸을 생성
                   # 그 안에 데이터를 저장해요!
#a.extend([4,5,6])  # list를 확장  
#print(a)

#a = [7,3,9,4,6,1,8]
# list를 정렬(오름차순, 내림차순)
#a.sort()   # list가 가지고 있는 함수. 원본이 변경
#result = sorted(a)   # python이 제공하는 함수
#print(a)
#print(result)

#a = ["Hello", "kaka","World", "haha"]
#a.sort()   # 정렬의 기본(오름차순)
           # 문자일경우 ASCII 코드를 기반으로 정렬
#print(a)    

# a = ["홍길동","최길동","아이유","김연아","신사임당"]
# a.sort()   # 정렬의 기본(오름차순)
#            # 문자일경우 ASCII 코드를 기반으로 정렬
# a.reverse() # 리스트를 역순으로 나열하는 함수
# print(a)    

a = [1,2,3,4,5]
#print(a.index(5))  # 찾은다음 찾은 위치를 return
#insert(1,"Hello") # 특정위치에 값을 삽입할 수 있어요!
#a.remove(3)        # 첫번째로 발견한 요소를 삭제
#print(a.pop())      # 맨 마지막 요소를 뜯어와요!
#print(a.pop(2))    # 지정한 위치에 요소를 뜯어와요!
#print(a)

#a = [1,2,3,4,5,1,2,1,3,4]
#print(a.count(1))   # list안에 내가 찾으려는 요소가
                    # 몇 개 있는지를 return
################
a = [1,2,3]
b = a[:]  # b = [1,2,3]
print(a == b)  # a와 b의 내용이 같은지를 물어봐요!
print(a is b)  # a와 b가 동일한 놈인지를 비교
# Out:
# True
# False

# %%
# Sequence Type : tuple
# list와 거의 동일
# 표현하는 방식이 달라요!
# list는 대괄호로 표현 [1,2,3]
# tuple 소괄호로 표현 (1,2,3)
#a = ()  # empty tuple
#myList = [1]   # 요소가 1개인 list
#print(type(myList))
#myTuple = (1,)  # 요소가 1개인 tuple
#print(type(myTuple))

myTuple = (1,2,3)   # tuple을 생성해요!
myTuple = 1,2,3     # tuple을 생성해요! () 생략가능
# tuple은 list와 비슷해요!
#print(myTuple[0:2])   # indexing & slicing 둘다 가능
#myTuple[0] = 100  # 이거 안되요! read only

a,b,c = 10,20,30
(a,b,c) = (10,20,30)
print(a)

# list와 tuple
#a = [1,2,3]  # list
#b = tuple(a) # tuple
#print(b)
#c = list(b)  # list
#print(c)

# sequence type : range
range1 = range(10)
print(range1)

range2 = range(1,11,2)   # [1,3,5,7,9]형태로 인식
print(range2)
# 숫자 영역을 잡는 range는 일반적으로 for
# 구문을 사용할때 많이 이용
# Out:
# 10
# range(0, 10)
# range(1, 11, 2)

# %%
# sequence type에는 결과적으로 3개가 존재
# list, tuple, range

# Mapping Type : dict (dictionary)
# key와 value의 쌍으로 표현되는 자료구조
# JSON ( { name : "홍길동", age : 30 })
# a = { "name" : "홍길동", "age" : 30 }
# print(type(a))
# key값은 불변의 값을 사용해야 해요!
# list는 key로 사용을 할 수 가 없어요!
# tuple는 key로 사용할 수 있어요!
# a[10] = "hohoho"
# a["hobby"] = "Game"
# print(a)
# print(a["age"])
# a = { "name" : "홍길동", "age" : 30, "age" : 40} # NG
# print(a)

# a = { "name" : "홍길동", ("address",) : "서울"}
# print(a)
# print(a[("address",)])

################################

# dict의 함수
a = { "name" : "홍길동", "age" : 20, "address" : "서울"}
# value을 가져오고 싶어요! => key을 알아야해요
#a.keys() # dict_keys 자료구조로 리턴
         # list와 유사한 자료구조
# myKey = a.keys()
# print(myKey)
# myList = list(myKey)
# print(myList)
#myValue = a.values() # dict_values 형태로 가져와요
#print(myValue)
# myItem = a.items()
# print(myItem)
# dict안에 있는 모든 key와 value를 출력하세요!
# for문을 이용해서
a = { "name" : "홍길동", "age" : 20, "address" : "서울"}
for k in a.keys():
    print("{} - {}".format(k, a[k])) 
    
print("age" in a, end="\n") # 특정 key값이 dict에 있는지 확인
############################################

# %%
## python
## 1. 환경설정
##    - PyCharm IDE를 이용해서 개발
##      여러명이 같은 파일, 같은 프로젝트를 공유하면서
##      개발할때 유리
##      Interactive한 개발은 힘들어요!
##      데이터분석작업보다는 Web 개발이나 다른 application작성  
##    - Jupyter Notebook
##      Interactive한 개발이 가능해서 데이터분석에 대한
##      학습이나 실제 분석작업을 많이 해요!
##      여러명이 공동작업할 때는 불편불편!!
## 2. jupyter notebook 사용방법
##    - cell 생성, cell안의 코드 실행방법
##    - cell 삭제
##    - 기본적인 tool 사용법
## 3. python built-in types
##    - Numeric Type( int, float, complex )
##    - Text Sequence Type( str ) => 약간 길게 설명
##    - Sequence Type ( list, tuple, range )
##    - Mapping Type ( dict )
##    - Bool Type ( bool )  : True, False를 사용해요
##    - and : 논리연산자, or : 논리연산자, not : 논리연산자
##    - & : 비교연산자, bitwise연산
##    python에서 숫자 0은 False로 간주, 0이 아닌 모든 숫자 True
##    python에서 False는 숫자 0으로 변환,
##               True를 숫자로 바꾸면 1로 변환
##    10진수 5를 2진수 => 0101
##    10진수 1을 2진수 => 0001
##    True & False => 1 & 0 => 0001 & 0000 => 0000 => 0 => False
##    python은 다음의 경우를 False로 간주
##    숫자 0, 빈 문자열(""), 빈 리스트([]), 빈 튜플( () )
##    비어있는 dict ( {} ), None

##    2019-11-13 python의 남은 built-in type
##    Set type( set )
##    어떻게 생겼나요?? => {}
##    {} : 기본적으로 dict, dict는 {} 안에 key와 value로 구성
##    set은 {} 안에 요소만 들어가요
a = { "name" : "홍길동", "age" : 20 }  # dict
a = { 1, 2, 3 } # dict 표현인데 key가 없어요!
a = set()
a = set([1,2,3,4,5])
##    set이라는 자료구조는.. 기본적으로
##    순서가 없어요. 중복을 허용하지 않는 저장장소
#print(type(a))
## 간단하게 set 예제를 들어보아요!
a = set([1,2,3,4,1,2,3,1,2,3])  # set은 중복을 배제해요!
a = set("Hello")   # 문자열을 set으로 만들면 어떻게 되나요?

# set의 연산
a = { 1, 2, 3, 4 }   # set의 literal
b = { 3, 4 ,5 ,6 }  

# set => 집합 ( 집합연산, 교집합, 합집합, 차집합 )
print(a & b)   # & : 만약 set에 적용하면 교집합(intersection)
print(a.intersection(b))
print(a | b)   # | : 만약 set에 적용하면 합집합(union)
print(a.union(b))
print(a - b)   # - : 만약 set에 적용하면 차집합(difference) 
print(a.difference(b))

mySet = {1, 2, 3, 4, 5}
mySet.add(7)   # add()는 set에 원하는 요소 1개를 추가
print(mySet)
mySet.update([10,11,12]) # 여러개를 set에 추가
print(mySet)
mySet.remove(1)   # 삭제
print(mySet)
# Out:
# {3, 4}
# {3, 4}
# {1, 2, 3, 4, 5, 6}
# {1, 2, 3, 4, 5, 6}
# {1, 2}
# {1, 2}
# {1, 2, 3, 4, 5, 7}
# {1, 2, 3, 4, 5, 7, 10, 11, 12}
# {2, 3, 4, 5, 7, 10, 11, 12}
