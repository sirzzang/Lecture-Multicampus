# %%
# module import
import pandas as pd
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.ensemble import IsolationForest
# from sklearn.metrics.pairwise import cosine_distances

# 경로 설정
root_path = "/content/drive/My Drive/멀티캠퍼스/[혁신성장] 인공지능 자연어처리 기반/[강의]/조성현 강사님"
data_path = f"{root_path}/dataset"

# 데이터 로드
credit = pd.read_csv(f"{data_path}/creditcard_fraud.csv")

########## ======== 원본 데이터 보존 ======== ################ 
# 피쳐 선택: Time 제외 모두 사용
X_data = credit.iloc[:, 1:-1]
y_train = credit.iloc[:, -1]

# 표준화
scaler = StandardScaler()
scaler.fit(X_data)
X_train = scaler.transform(X_data)
X_train
print(X_train)
print(y_train)

########## ======== 오토인코더 모델 구성 ======== ################ 
X_train_AE = X_train.copy()

# 파라미터 설정
n_input = X_train_AE.shape[1]
n_output = n_input

# 모델 레이어 설정
x_Input = Input(batch_shape=(None, n_input))
x_Encoder1 = Dense(256, activation='relu')(x_Input)
x_Encoder1 = Dropout(0.3)(x_Encoder1)
x_Encoder2 = Dense(512, activation='relu')(x_Encoder1)
x_Encoder2 = Dropout(0.2)(x_Encoder2)
y_Decoder1 = Dense(256, activation='relu')(x_Encoder2)
y_Decoder1 = Dropout(0.3)(y_Decoder1)
y_Decoder2 = Dense(n_output, activation='linear')(y_Decoder1)

# 모델 구조 설정
model = Model(x_Input, y_Decoder2)
model.compile(loss='mse', optimizer=Adam(lr=0.001))
print("====== 모델 전체 구조 ======")
print(model.summary())

# 모델 학습 파라미터, 체크포인트
# EPOCHS = int(input('학습 횟수 설정: '))
# BATCH = int(input('배치 사이즈 설정: '))
EPOCHS = 500
BATCH = 500
es = EarlyStopping(monitor='loss', patience=5, verbose=1)

# 훈련
hist = model.fit(X_train_AE, X_train_AE,
                 epochs=EPOCHS,
                 batch_size=BATCH,
                 callbacks=[es],
                 shuffle=True)

# plot loss
plt.plot(hist.history['loss'], label='Train Loss')
plt.title('Loss Trajectory_AutoEncoder')
plt.legend()
plt.show()

# 예측
y_pred_AE = model.predict(X_train_AE)
y_pred_AE

# 거리 계산: 불확실!!
def calc_distance(origin, pred):
    dist = []
    for i in range(len(pred)):
        dist.append(np.sqrt(np.sum((np.square(origin[i]-pred[i])))))
    dist = np.array(dist)
    return pd.Series(dist)

# %%time
distance_AE = calc_distance(X_train_AE, y_pred_AE)

# 원래 데이터에 넣기
credit['distance_AE'] = distance_AE
display(credit)


########## ======== isolationForest 모델 구성 ======== ################ 

# 데이터 준비 
X_train_IF = X_train.copy()
y_train_IF = y_train.copy()
print(X_train_IF)
print(y_train_IF)

# iForest 학습
model = IsolationForest(n_estimators=200, verbose=1)
model.fit(X_train_IF)

# 이상치 점수 by 거리
score = abs(model.score_samples(X_train_IF))

# 이상치 점수 시각화
plt.hist(score, bins=50)
plt.show()

# 이상치 점수 기준: 0.7
y_pred_IF = (score > 0.7).astype(int)
print(y_pred_IF)

# iForest 라벨 원래 데이터에 넣기
credit['Class_iForest'] = pd.Series(y_pred_IF)
display(credit)

########## ======== 3) 결과 비교 ======== ################ 

# AE 거리 순 정렬
df = credit.sort_values(by='distance_AE', ascending=False)
display(df)

# 각 라벨 확인 원래 몇 개 있는지 확인
print(df['Class'].value_counts()) # original label 이상치 : 492
print(df['Class_iForest'].value_counts()) # iForest label 이상치 : 207

# AE로 계산한 거리 상위 n개 중 이상치 몇 개 있는지 반환
def count_abnormal(data, threshold, num=30):
    for i in range(threshold//num):
        print(f"<< 상위 {(i+1)*num}개에서 이상치 체크 >> ")
        print("  ====== AutoEncoder vs. Original Label ======")
        print(data['Class'][:(i+1)*num].value_counts())        
        print("  ====== AutoEncoder vs. iForest Label ======")
        print(data['Class_iForest'][:(i+1)*num].value_counts())
        print(" ")

# 원래 이상치 데이터 492개이므로 AE 기준 거리 상위 600개 데이터 정도 까지만 비교
count_abnormal(df, 600)
# Out:
# [[-0.69424232 -0.04407492  1.6727735  ...  0.33089162 -0.06378115
#    0.24496426]
#  [ 0.60849633  0.16117592  0.1097971  ... -0.02225568  0.04460752
#   -0.34247454]
#  [-0.69350046 -0.81157783  1.16946849 ... -0.13713686 -0.18102083
#    1.16068593]
#  ...
#  [ 0.98002374 -0.18243372 -2.14320514 ...  0.01103672 -0.0804672
#   -0.0818393 ]
#  [-0.12275539  0.32125034  0.46332013 ...  0.26960398  0.31668678
#   -0.31324853]
#  [-0.27233093 -0.11489898  0.46386564 ... -0.00598394  0.04134998
#    0.51435531]]
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64
# ====== 모델 전체 구조 ======
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 29)]              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               7680
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 29)                7453
# =================================================================
# Total params: 278,045
# Trainable params: 278,045
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.2437
# Epoch 2/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1632
# Epoch 3/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1478
# Epoch 4/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1385
# Epoch 5/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1322
# Epoch 6/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1384
# Epoch 7/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1297
# Epoch 8/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1286
# Epoch 9/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1231
# Epoch 10/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1221
# Epoch 11/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1233
# Epoch 12/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1237
# Epoch 13/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1213
# Epoch 14/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1171
# Epoch 15/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1174
# Epoch 16/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1225
# Epoch 17/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1196
# Epoch 18/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1187
# Epoch 19/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1155
# Epoch 20/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1149
# Epoch 21/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1148
# Epoch 22/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1152
# Epoch 23/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1141
# Epoch 24/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1149
# Epoch 25/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1147
# Epoch 26/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1156
# Epoch 27/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1135
# Epoch 28/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1161
# Epoch 29/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1152
# Epoch 30/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1114
# Epoch 31/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1115
# Epoch 32/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1111
# Epoch 33/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1118
# Epoch 34/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1148
# Epoch 35/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1134
# Epoch 36/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1118
# Epoch 37/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1100
# Epoch 38/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1109
# Epoch 39/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1122
# Epoch 40/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1116
# Epoch 41/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1110
# Epoch 42/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1094
# Epoch 43/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1104
# Epoch 44/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1120
# Epoch 45/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1095
# Epoch 46/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1106
# Epoch 47/500
# 570/570 [==============================] - 1s 2ms/step - loss: 0.1101
# Epoch 00047: early stopping
#             Time         V1         V2  ...  Amount  Class  distance_AE
# 0            0.0  -1.359807  -0.072781  ...  149.62      0     0.454599
# 1            0.0   1.191857   0.266151  ...    2.69      0     0.250078
# 2            1.0  -1.358354  -1.340163  ...  378.66      0     1.135642
# 3            1.0  -0.966272  -0.185226  ...  123.50      0     0.529790
# 4            2.0  -1.158233   0.877737  ...   69.99      0     0.414916
# ...          ...        ...        ...  ...     ...    ...          ...
# 284802  172786.0 -11.881118  10.071785  ...    0.77      0     2.243277
# 284803  172787.0  -0.732789  -0.055080  ...   24.79      0     0.616035
# 284804  172788.0   1.919565  -0.301254  ...   67.88      0     0.448857
# 284805  172788.0  -0.240440   0.530483  ...   10.00      0     0.792846
# 284806  172792.0  -0.533413  -0.189733  ...  217.00      0     0.512758
#
# [284807 rows x 32 columns]
# [[-0.69424232 -0.04407492  1.6727735  ...  0.33089162 -0.06378115
#    0.24496426]
#  [ 0.60849633  0.16117592  0.1097971  ... -0.02225568  0.04460752
#   -0.34247454]
#  [-0.69350046 -0.81157783  1.16946849 ... -0.13713686 -0.18102083
#    1.16068593]
#  ...
#  [ 0.98002374 -0.18243372 -2.14320514 ...  0.01103672 -0.0804672
#   -0.0818393 ]
#  [-0.12275539  0.32125034  0.46332013 ...  0.26960398  0.31668678
#   -0.31324853]
#  [-0.27233093 -0.11489898  0.46386564 ... -0.00598394  0.04134998
#    0.51435531]]
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   13.7s finished
# [0 0 0 ... 0 0 0]
#             Time         V1         V2  ...  Class  distance_AE  Class_iForest
# 0            0.0  -1.359807  -0.072781  ...      0     0.454599              0
# 1            0.0   1.191857   0.266151  ...      0     0.250078              0
# 2            1.0  -1.358354  -1.340163  ...      0     1.135642              0
# 3            1.0  -0.966272  -0.185226  ...      0     0.529790              0
# 4            2.0  -1.158233   0.877737  ...      0     0.414916              0
# ...          ...        ...        ...  ...    ...          ...            ...
# 284802  172786.0 -11.881118  10.071785  ...      0     2.243277              0
# 284803  172787.0  -0.732789  -0.055080  ...      0     0.616035              0
# 284804  172788.0   1.919565  -0.301254  ...      0     0.448857              0
# 284805  172788.0  -0.240440   0.530483  ...      0     0.792846              0
# 284806  172792.0  -0.533413  -0.189733  ...      0     0.512758              0
#
# [284807 rows x 33 columns]
#             Time         V1         V2  ...  Class  distance_AE  Class_iForest
# 154684  102572.0 -28.709229  22.057729  ...      1    45.235378              1
# 154587  102114.0 -28.255053  21.467203  ...      1    43.142809              1
# 274771  166198.0 -35.548539 -31.850484  ...      0    37.746673              1
# 154371  101313.0 -25.825982  19.167239  ...      1    34.792845              1
# 39769    39954.0 -56.407510 -72.715728  ...      0    34.675420              1
# ...          ...        ...        ...  ...    ...          ...            ...
# 91081    63306.0   1.158216   0.095187  ...      0     0.186626              0
# 139788   83358.0   1.157999   0.085013  ...      0     0.183029              0
# 106624   70043.0   1.154287   0.198589  ...      0     0.182736              0
# 14995    26319.0   1.139049   0.078237  ...      0     0.182056              0
# 103576   68719.0   1.146523   0.066050  ...      0     0.178750              0
#
# [284807 rows x 33 columns]
# 0    284315
# 1       492
# Name: Class, dtype: int64
# 0    284630
# 1       177
# Name: Class_iForest, dtype: int64
# << 상위 30개에서 이상치 체크 >>
#   ====== AutoEncoder vs. Original Label ======
# 0    20
# 1    10
# Name: Class, dtype: int64
#   ====== AutoEncoder vs. iForest Label ======
# 1    24
# 0     6
# Name: Class_iForest, dtype: int64
#
# << 상위 60개에서 이상치 체크 >>
#   ====== AutoEncoder vs. Original Label ======
# 0    35
# 1    25
# Name: Class, dtype: int64
#   ====== AutoEncoder vs. iForest Label ======
# 1    45
# 0    15
# Name: Class_iForest, dtype: int64
#
# << 상위 90개에서 이상치 체크 >>
#   ====== AutoEncoder vs. Original Label ======
# 0    46
# 1    44
# Name: Class, dtype: int64
#   ====== AutoEncoder vs. iForest Label ======
# 1    59
# 0    31
# Name: Class_iForest, dtype: int64
#
# << 상위 120개에서 이상치 체크 >>
#   ====== AutoEncoder vs. Original Label ======
# 1    60
# 0    60
# Name: Class, dtype: int64
#   ====== AutoEncoder vs. iForest Label ======
# 1    76
# 0    44
# Name: Class_iForest, dtype: int64
#
# << 상위 150개에서 이상치 체크 >>
#   ====== AutoEncoder vs. Original Label ======
# 0    81
# 1    69
# Name: Class, dtype: int64
#   ====== AutoEncoder vs. iForest Label ======
# 1    88
# 0    62
# Name: Class_iForest, dtype: int64
#
# << 상위 180개에서 이상치 체크 >>
#   ====== AutoEncoder vs. Original Label ======
# 0    97
# 1    83
# Name: Class, dtype: int64
#   ====== AutoEncoder vs. iForest Label ======
# 1    100
# 0     80
# Name: Class_iForest, dtype: int64
#
# << 상위 210개에서 이상치 체크 >>
#   ====== AutoEncoder vs. Original Label ======
# 0    116
# 1     94
# Name: Class, dtype: int64
#   ====== AutoEncoder vs. iForest Label ======
# 1    110
# 0    100
# Name: Class_iForest, dtype: int64
#
# << 상위 240개에서 이상치 체크 >>
#   ====== AutoEncoder vs. Original Label ======
# 0    142
# 1     98
# Name: Class, dtype: int64
#   ====== AutoEncoder vs. iForest Label ======
# 1    121
# 0    119
# Name: Class_iForest, dtype: int64
#
# << 상위 270개에서 이상치 체크 >>
#   ====== AutoEncoder vs. Original Label ======
# 0    166
# 1    104
# Name: Class, dtype: int64
#   ====== AutoEncoder vs. iForest Label ======
# 0    145
# 1    125
# Name: Class_iForest, dtype: int64
#
# << 상위 300개에서 이상치 체크 >>
#   ====== AutoEncoder vs. Original Label ======
# 0    190
# 1    110
# Name: Class, dtype: int64
#   ====== AutoEncoder vs. iForest Label ======
# 0    164
# 1    136
# Name: Class_iForest, dtype: int64
#
# << 상위 330개에서 이상치 체크 >>
#   ====== AutoEncoder vs. Original Label ======
# 0    212
# 1    118
# Name: Class, dtype: int64
#   ====== AutoEncoder vs. iForest Label ======
# 0    190
# 1    140
# Name: Class_iForest, dtype: int64
#
# << 상위 360개에서 이상치 체크 >>
#   ====== AutoEncoder vs. Original Label ======
# 0    235
# 1    125
# Name: Class, dtype: int64
#   ====== AutoEncoder vs. iForest Label ======
# 0    219
# 1    141
# Name: Class_iForest, dtype: int64
#
# << 상위 390개에서 이상치 체크 >>
#   ====== AutoEncoder vs. Original Label ======
# 0    255
# 1    135
# Name: Class, dtype: int64
#   ====== AutoEncoder vs. iForest Label ======
# 0    243
# 1    147
# Name: Class_iForest, dtype: int64
#
# << 상위 420개에서 이상치 체크 >>
#   ====== AutoEncoder vs. Original Label ======
# 0    277
# 1    143
# Name: Class, dtype: int64
#   ====== AutoEncoder vs. iForest Label ======
# 0    268
# 1    152
# Name: Class_iForest, dtype: int64
#
# << 상위 450개에서 이상치 체크 >>
#   ====== AutoEncoder vs. Original Label ======
# 0    297
# 1    153
# Name: Class, dtype: int64
#   ====== AutoEncoder vs. iForest Label ======
# 0    295
# 1    155
# Name: Class_iForest, dtype: int64
#
# << 상위 480개에서 이상치 체크 >>
#   ====== AutoEncoder vs. Original Label ======
# 0    316
# 1    164
# Name: Class, dtype: int64
#   ====== AutoEncoder vs. iForest Label ======
# 0    317
# 1    163
# Name: Class_iForest, dtype: int64
#
# << 상위 510개에서 이상치 체크 >>
#   ====== AutoEncoder vs. Original Label ======
# 0    341
# 1    169
# Name: Class, dtype: int64
#   ====== AutoEncoder vs. iForest Label ======
# 0    344
# 1    166
# Name: Class_iForest, dtype: int64
#
# << 상위 540개에서 이상치 체크 >>
#   ====== AutoEncoder vs. Original Label ======
# 0    368
# 1    172
# Name: Class, dtype: int64
#   ====== AutoEncoder vs. iForest Label ======
# 0    373
# 1    167
# Name: Class_iForest, dtype: int64
#
# << 상위 570개에서 이상치 체크 >>
#   ====== AutoEncoder vs. Original Label ======
# 0    390
# 1    180
# Name: Class, dtype: int64
#   ====== AutoEncoder vs. iForest Label ======
# 0    403
# 1    167
# Name: Class_iForest, dtype: int64
#
# << 상위 600개에서 이상치 체크 >>
#   ====== AutoEncoder vs. Original Label ======
# 0    420
# 1    180
# Name: Class, dtype: int64
#   ====== AutoEncoder vs. iForest Label ======
# 0    433
# 1    167
# Name: Class_iForest, dtype: int64
