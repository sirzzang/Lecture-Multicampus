# %% [markdown]
#  앞의 코드와 크게 다르지 않으나, 2차원 데이터를 입력한다. 따라서 분포가 3차원이 된다. 시각화하여 확인할 때는 위에서 내려다 본 모양으로 확인한다.

# %%
# module import
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras import backend as K
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# eager execution 기능 끄기
tf.compat.v1.disable_eager_execution()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # _1_. 데이터 생성

# %%
# 데이터 생성
def createDataSet(n):
    xy = []
    for _ in range(n):
        r = np.random.random()
        if r < 0.25:
            x = np.random.normal(0.0, 0.5)
            y = np.random.normal(0.0, 0.5)
        elif r < 0.50:
            x = np.random.normal(0.0, 0.5)
            y = np.random.normal(2.0, 0.5)
        elif r < 0.75:
            x = np.random.normal(2.0, 0.5)
            y = np.random.normal(0.0, 0.5)
        else:
            x = np.random.normal(2.0, 0.5)
            y = np.random.normal(2.0, 0.5)
        
        xy.append([x, y])

    return pd.DataFrame(xy, columns = ['x', 'y'])

# %%
# 데이터셋 생성
ds = createDataSet(n=2000)
display(ds)
real_data = np.array(ds)
# Out:
#              x         y
# 0     2.349468  0.498128
# 1     0.624600  2.476031
# 2     2.649507  0.708346
# 3    -0.494450  2.716464
# 4     2.017854 -0.562040
# ...        ...       ...
# 1995  0.978130  2.108541
# 1996 -0.009260  0.935344
# 1997  1.938168 -0.553922
# 1998 -0.743832 -0.568912
# 1999  0.123230  2.431169
#
# [2000 rows x 2 columns]

# %%
# 파라미터 설정
d_input = real_data.shape[1]
d_hidden = 128 # 조금 더 깊게 구성했다.
d_output = 1 # 주의
g_input = 16
g_hidden = 128
g_output = d_input

# %% [markdown]
# # _2_. 필요한 함수 만들기
#
# - 이 실습에서는 KL divergence 계산하지 않는다.

# %%
# def calc_KL(P, Q):
    
#     hist_P, bins_P = np.histogram(P, bins=100)
#     hist_Q, bins_Q = np.histogram(Q, bins=bins_P)

#     # pdf로 만들기 위해 정규화
#     hist_P = hist_P / (np.sum(hist_P) + 1e-8) # 분모 0 방지
#     hist_Q = hist_Q / (np.sum(hist_Q) + 1e-8) 

#     # KL divergence 계산
#     kld = np.sum(hist_P * (np.log(hist_P + 1e-8) - np.log(hist_Q + 1e-8)))

#     return kld

# %%
def getNoise(m, n=g_input):
    z = np.random.uniform(-1.0, 1.0, size=[m, n])
    return z

# %%
def myOptimizer(a):
    return RMSprop(learning_rate=a)

# %% [markdown]
# # _2_. Discriminator
# - label을 붙일 (나중의) Input과 그것이 진짜인지(1) 가짜인지(0) 판단해서 sigmoid로 출력해 주는 Output이 있다.
# - Input, Output의 모델을 생성한다.
# - discriminator는 학습한다.

# %%
def build_discriminator():
    d_x = Input(batch_shape=(None, d_input))
    d_h = Dense(d_hidden, activation='relu')(d_x)
    d_o = Dense(d_output, activation='sigmoid')(d_h)
    
    d_model = Model(d_x, d_o)
    d_model.compile(loss='binary_crossentropy', optimizer=myOptimizer(0.001))
    
    return d_model

# %% [markdown]
# # _3_. Generator
# * 가짜 데이터를 생성한다.
# * 모델을 만들기는 하나, 학습은 하지 않는다. 따라서 compile하지 않는다.
# * 출력 시 활성화는 그대로 출력하도록 하는 linear이다.

# %%
def build_generator():
    g_x = Input(batch_shape=(None, g_input))
    g_h = Dense(g_hidden, activation='relu')(g_x)
    g_o = Dense(g_output, activation='linear')(g_h)

    g_model = Model(g_x, g_o)
    
    return g_model

# %% [markdown]
# # _4_. GAN 네트워크
#
# ```
#         +---+   Gz   +---+
#   z --->| G |------->| D |---> DGz
#         +---+        +---+
#       trainable   not trainable
# ```
#
# * 기본적으로 z가 들어가면, DGz가 1이 나오도록 G가 학습된다.
# * 이 때 D는 위에서 학습하므로, G의 네트워크만 업데이트한다.
# * G는 여기서 학습된다. 컴파일을 여기서!
#     - 이진 분류 지도 학습 문제로 바꾸어 풀기 때문에, loss는 `binary_crossentropy`.

# %%
def build_GAN(discriminator, generator):
    discriminator.trainable = False # discriminator 업데이트 해제
    
    z = Input(batch_shape=(None, g_input))
    Gz = generator(z)
    DGz = discriminator(Gz)

    gan_model = Model(z, DGz)
    gan_model.compile(loss='binary_crossentropy', optimizer = myOptimizer(0.0005))

    return gan_model

# %% [markdown]
# # _5_. 학습
# - 그래프 초기화 왜 있죠?
# - PyTorch에서 마지막이면 끝 데이터까지 쓰는 거 훨씬 쉽게 사용할 수 있을 듯!
# - G(generator) 자체를 모델로 만들었기 때문에, `model.predict` 해야 노이즈 데이터 생성할 수 있음.
# - `.fit`보다 `.train_on_batch`
# - 학습 방식: D 1회, G 1회 --> 이렇게 한 번 돌아야 에폭 1회.
# - generator : GAN 네트워크 자체에서 학습됨.
#
# ---
#
# - ? `*2` 왜? batch 안에 들어 있는 개수만큼 generate했으므로!
# - generator는 `X_Batch.shape[0]`만 해준다? 제너레이터는 만들어 내는 것에 대해서만 학습??
# - `g_target[:]`으로 해야 바뀜!

# %%
# 그래프 초기화
K.clear_session()
D = build_discriminator()
G = build_generator()
GAN = build_GAN(D, G)

n_batch_cnt = int(input('입력 데이터 배치 블록 수 설정: '))
n_batch_size = int(real_data.shape[0] / n_batch_cnt) # 배치 블록 당 사이즈
EPOCHS = int(input('학습 횟수 설정: '))

for epoch in range(EPOCHS):

    # 미니배치 학습
    for n in range(n_batch_cnt):
        from_, to_ = n*n_batch_size, (n+1)*n_batch_size

        # 마지막 루프라면 to_는 끝까지
        if n == n_batch_cnt - 1:
            to_ = real_data.shape[0]
        
        # 학습 데이터 배치로 준비
        X_batch = real_data[from_ : to_]
        Z_batch = getNoise(m = X_batch.shape[0], n = g_input)
        Gz = G.predict(Z_batch) # predict 해야 제너레이터가 만들어낼 수 있음.

        # discriminator 학습을 위한 데이터 준비
        d_target = np.zeros(X_batch.shape[0] * 2) # batch 안에 들어 있는 개수만큼 generate
        d_target[:X_batch.shape[0]] = 0.9 # 1.0 대신 0.9
        d_target[X_batch.shape[0]:] = 0.1 # 0.0 대신 0.1

        # discriminator 학습
        X_batch_Gz = np.concatenate([X_batch, Gz])
        loss_discriminator = D.train_on_batch(X_batch_Gz, d_target)

        # generator 학습
        g_target = np.zeros(X_batch.shape[0])
        g_target[:] = 0.9
        loss_generator = GAN.train_on_batch(Z_batch, g_target)

    if epoch % 10 == 0:
        z = getNoise(m = real_data.shape[0], n=g_input)
        fake_data = G.predict(z) # generator 모델이 가짜 분포 생성
        # kld = calc_KL(real_data, fake_data) # KL Divergence 계산
        # print(f"epoch: %d, D-Loss = %.4f, G-Loss = %.4f, KL-divergence = %.4f" % (epoch, loss_discriminator, loss_generator, kld))
        print(f"epoch: %d, D-Loss = %.4f, G-Loss = %.4f" % (epoch, loss_discriminator, loss_generator))
# Out:
# 입력 데이터 배치 블록 수 설정: 4
# 학습 횟수 설정: 3000
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, D-Loss = 0.6460, G-Loss = 0.6991
# epoch: 10, D-Loss = 0.6280, G-Loss = 0.6557
# epoch: 20, D-Loss = 0.6332, G-Loss = 0.7520
# epoch: 30, D-Loss = 0.6617, G-Loss = 0.7955
# epoch: 40, D-Loss = 0.6845, G-Loss = 0.7687
# epoch: 50, D-Loss = 0.7014, G-Loss = 0.7339
# epoch: 60, D-Loss = 0.6998, G-Loss = 0.6910
# epoch: 70, D-Loss = 0.6858, G-Loss = 0.7091
# epoch: 80, D-Loss = 0.6880, G-Loss = 0.7097
# epoch: 90, D-Loss = 0.6892, G-Loss = 0.7131
# epoch: 100, D-Loss = 0.6875, G-Loss = 0.7071
# epoch: 110, D-Loss = 0.6887, G-Loss = 0.7056
# epoch: 120, D-Loss = 0.6852, G-Loss = 0.7158
# epoch: 130, D-Loss = 0.6864, G-Loss = 0.7069
# epoch: 140, D-Loss = 0.6851, G-Loss = 0.7115
# epoch: 150, D-Loss = 0.6834, G-Loss = 0.7128
# epoch: 160, D-Loss = 0.6782, G-Loss = 0.7138
# epoch: 170, D-Loss = 0.6788, G-Loss = 0.7245
# epoch: 180, D-Loss = 0.6756, G-Loss = 0.7286
# epoch: 190, D-Loss = 0.6804, G-Loss = 0.7185
# epoch: 200, D-Loss = 0.6784, G-Loss = 0.7399
# epoch: 210, D-Loss = 0.6756, G-Loss = 0.7277
# epoch: 220, D-Loss = 0.6725, G-Loss = 0.7224
# epoch: 230, D-Loss = 0.6811, G-Loss = 0.7258
# epoch: 240, D-Loss = 0.6789, G-Loss = 0.7383
# epoch: 250, D-Loss = 0.6781, G-Loss = 0.7370
# epoch: 260, D-Loss = 0.6785, G-Loss = 0.7291
# epoch: 270, D-Loss = 0.6799, G-Loss = 0.7408
# epoch: 280, D-Loss = 0.6834, G-Loss = 0.7291
# epoch: 290, D-Loss = 0.6829, G-Loss = 0.7292
# epoch: 300, D-Loss = 0.6816, G-Loss = 0.7207
# epoch: 310, D-Loss = 0.6847, G-Loss = 0.7410
# epoch: 320, D-Loss = 0.6851, G-Loss = 0.7231
# epoch: 330, D-Loss = 0.6860, G-Loss = 0.7094
# epoch: 340, D-Loss = 0.6852, G-Loss = 0.7182
# epoch: 350, D-Loss = 0.6847, G-Loss = 0.7143
# epoch: 360, D-Loss = 0.6889, G-Loss = 0.7235
# epoch: 370, D-Loss = 0.6877, G-Loss = 0.7268
# epoch: 380, D-Loss = 0.6841, G-Loss = 0.7372
# epoch: 390, D-Loss = 0.6864, G-Loss = 0.7338
# epoch: 400, D-Loss = 0.6912, G-Loss = 0.7100
# epoch: 410, D-Loss = 0.6905, G-Loss = 0.7594
# epoch: 420, D-Loss = 0.6893, G-Loss = 0.7202
# epoch: 430, D-Loss = 0.6897, G-Loss = 0.7347
# epoch: 440, D-Loss = 0.6910, G-Loss = 0.7278
# epoch: 450, D-Loss = 0.6889, G-Loss = 0.7107
# epoch: 460, D-Loss = 0.6914, G-Loss = 0.7320
# epoch: 470, D-Loss = 0.6909, G-Loss = 0.7049
# epoch: 480, D-Loss = 0.6910, G-Loss = 0.6993
# epoch: 490, D-Loss = 0.6905, G-Loss = 0.7148
# epoch: 500, D-Loss = 0.6898, G-Loss = 0.7142
# epoch: 510, D-Loss = 0.6906, G-Loss = 0.7119
# epoch: 520, D-Loss = 0.6909, G-Loss = 0.7183
# epoch: 530, D-Loss = 0.6919, G-Loss = 0.7023
# epoch: 540, D-Loss = 0.6906, G-Loss = 0.7009
# epoch: 550, D-Loss = 0.6948, G-Loss = 0.7370
# epoch: 560, D-Loss = 0.6918, G-Loss = 0.7310
# epoch: 570, D-Loss = 0.6910, G-Loss = 0.7199
# epoch: 580, D-Loss = 0.6945, G-Loss = 0.7098
# epoch: 590, D-Loss = 0.6907, G-Loss = 0.6920
# epoch: 600, D-Loss = 0.6933, G-Loss = 0.7119
# epoch: 610, D-Loss = 0.6955, G-Loss = 0.7070
# epoch: 620, D-Loss = 0.6919, G-Loss = 0.7121
# epoch: 630, D-Loss = 0.6916, G-Loss = 0.7203
# epoch: 640, D-Loss = 0.6923, G-Loss = 0.6926
# epoch: 650, D-Loss = 0.6939, G-Loss = 0.7067
# epoch: 660, D-Loss = 0.6932, G-Loss = 0.6897
# epoch: 670, D-Loss = 0.6931, G-Loss = 0.7246
# epoch: 680, D-Loss = 0.6932, G-Loss = 0.7152
# epoch: 690, D-Loss = 0.6932, G-Loss = 0.7148
# epoch: 700, D-Loss = 0.6925, G-Loss = 0.6946
# epoch: 710, D-Loss = 0.6926, G-Loss = 0.7116
# epoch: 720, D-Loss = 0.6929, G-Loss = 0.6954
# epoch: 730, D-Loss = 0.6929, G-Loss = 0.7044
# epoch: 740, D-Loss = 0.6942, G-Loss = 0.6879
# epoch: 750, D-Loss = 0.6926, G-Loss = 0.7050
# epoch: 760, D-Loss = 0.6944, G-Loss = 0.7085
# epoch: 770, D-Loss = 0.6938, G-Loss = 0.7087
# epoch: 780, D-Loss = 0.6944, G-Loss = 0.7199
# epoch: 790, D-Loss = 0.6933, G-Loss = 0.6841
# epoch: 800, D-Loss = 0.6919, G-Loss = 0.7028
# epoch: 810, D-Loss = 0.6915, G-Loss = 0.6945
# epoch: 820, D-Loss = 0.6923, G-Loss = 0.7254
# epoch: 830, D-Loss = 0.6924, G-Loss = 0.7153
# epoch: 840, D-Loss = 0.6930, G-Loss = 0.7075
# epoch: 850, D-Loss = 0.6928, G-Loss = 0.7033
# epoch: 860, D-Loss = 0.6929, G-Loss = 0.6897
# epoch: 870, D-Loss = 0.6937, G-Loss = 0.6955
# epoch: 880, D-Loss = 0.6922, G-Loss = 0.6997
# epoch: 890, D-Loss = 0.6934, G-Loss = 0.7033
# epoch: 900, D-Loss = 0.6929, G-Loss = 0.7097
# epoch: 910, D-Loss = 0.6929, G-Loss = 0.6936
# epoch: 920, D-Loss = 0.6931, G-Loss = 0.6848
# epoch: 930, D-Loss = 0.6926, G-Loss = 0.7110
# epoch: 940, D-Loss = 0.6930, G-Loss = 0.6929
# epoch: 950, D-Loss = 0.6937, G-Loss = 0.7226
# epoch: 960, D-Loss = 0.6917, G-Loss = 0.7041
# epoch: 970, D-Loss = 0.6929, G-Loss = 0.7078
# epoch: 980, D-Loss = 0.6935, G-Loss = 0.7153
# epoch: 990, D-Loss = 0.6920, G-Loss = 0.6936
# epoch: 1000, D-Loss = 0.6932, G-Loss = 0.6881
# epoch: 1010, D-Loss = 0.6928, G-Loss = 0.6911
# epoch: 1020, D-Loss = 0.6932, G-Loss = 0.7273
# epoch: 1030, D-Loss = 0.6933, G-Loss = 0.7036
# epoch: 1040, D-Loss = 0.6931, G-Loss = 0.6989
# epoch: 1050, D-Loss = 0.6940, G-Loss = 0.7161
# epoch: 1060, D-Loss = 0.6927, G-Loss = 0.7177
# epoch: 1070, D-Loss = 0.6947, G-Loss = 0.7226
# epoch: 1080, D-Loss = 0.6928, G-Loss = 0.6965
# epoch: 1090, D-Loss = 0.6926, G-Loss = 0.6958
# epoch: 1100, D-Loss = 0.6933, G-Loss = 0.7113
# epoch: 1110, D-Loss = 0.6925, G-Loss = 0.6994
# epoch: 1120, D-Loss = 0.6937, G-Loss = 0.7286
# epoch: 1130, D-Loss = 0.6928, G-Loss = 0.6923
# epoch: 1140, D-Loss = 0.6924, G-Loss = 0.7097
# epoch: 1150, D-Loss = 0.6934, G-Loss = 0.7175
# epoch: 1160, D-Loss = 0.6923, G-Loss = 0.7082
# epoch: 1170, D-Loss = 0.6931, G-Loss = 0.6891
# epoch: 1180, D-Loss = 0.6929, G-Loss = 0.7078
# epoch: 1190, D-Loss = 0.6931, G-Loss = 0.7093
# epoch: 1200, D-Loss = 0.6926, G-Loss = 0.7003
# epoch: 1210, D-Loss = 0.6929, G-Loss = 0.6953
# epoch: 1220, D-Loss = 0.6934, G-Loss = 0.7076
# epoch: 1230, D-Loss = 0.6935, G-Loss = 0.7063
# epoch: 1240, D-Loss = 0.6922, G-Loss = 0.7062
# epoch: 1250, D-Loss = 0.6925, G-Loss = 0.6967
# epoch: 1260, D-Loss = 0.6929, G-Loss = 0.6981
# epoch: 1270, D-Loss = 0.6930, G-Loss = 0.7081
# epoch: 1280, D-Loss = 0.6929, G-Loss = 0.6933
# epoch: 1290, D-Loss = 0.6939, G-Loss = 0.7112
# epoch: 1300, D-Loss = 0.6934, G-Loss = 0.7012
# epoch: 1310, D-Loss = 0.6927, G-Loss = 0.6976
# epoch: 1320, D-Loss = 0.6930, G-Loss = 0.6994
# epoch: 1330, D-Loss = 0.6942, G-Loss = 0.7109
# epoch: 1340, D-Loss = 0.6938, G-Loss = 0.7016
# epoch: 1350, D-Loss = 0.6926, G-Loss = 0.7106
# epoch: 1360, D-Loss = 0.6937, G-Loss = 0.7088
# epoch: 1370, D-Loss = 0.6920, G-Loss = 0.7006
# epoch: 1380, D-Loss = 0.6931, G-Loss = 0.6940
# epoch: 1390, D-Loss = 0.6935, G-Loss = 0.7016
# epoch: 1400, D-Loss = 0.6928, G-Loss = 0.6971
# epoch: 1410, D-Loss = 0.6944, G-Loss = 0.7065
# epoch: 1420, D-Loss = 0.6931, G-Loss = 0.7120
# epoch: 1430, D-Loss = 0.6929, G-Loss = 0.7054
# epoch: 1440, D-Loss = 0.6925, G-Loss = 0.6942
# epoch: 1450, D-Loss = 0.6940, G-Loss = 0.7010
# epoch: 1460, D-Loss = 0.6932, G-Loss = 0.7059
# epoch: 1470, D-Loss = 0.6932, G-Loss = 0.6875
# epoch: 1480, D-Loss = 0.6936, G-Loss = 0.7042
# epoch: 1490, D-Loss = 0.6939, G-Loss = 0.6899
# epoch: 1500, D-Loss = 0.6935, G-Loss = 0.7059
# epoch: 1510, D-Loss = 0.6929, G-Loss = 0.6955
# epoch: 1520, D-Loss = 0.6925, G-Loss = 0.7158
# epoch: 1530, D-Loss = 0.6942, G-Loss = 0.7205
# epoch: 1540, D-Loss = 0.6933, G-Loss = 0.7244
# epoch: 1550, D-Loss = 0.6926, G-Loss = 0.6881
# epoch: 1560, D-Loss = 0.6921, G-Loss = 0.7070
# epoch: 1570, D-Loss = 0.6926, G-Loss = 0.7068
# epoch: 1580, D-Loss = 0.6932, G-Loss = 0.6906
# epoch: 1590, D-Loss = 0.6929, G-Loss = 0.6926
# epoch: 1600, D-Loss = 0.6937, G-Loss = 0.7163
# epoch: 1610, D-Loss = 0.6927, G-Loss = 0.7032
# epoch: 1620, D-Loss = 0.6928, G-Loss = 0.6911
# epoch: 1630, D-Loss = 0.6920, G-Loss = 0.7133
# epoch: 1640, D-Loss = 0.6941, G-Loss = 0.7177
# epoch: 1650, D-Loss = 0.6936, G-Loss = 0.7209
# epoch: 1660, D-Loss = 0.6935, G-Loss = 0.6997
# epoch: 1670, D-Loss = 0.6918, G-Loss = 0.7058
# epoch: 1680, D-Loss = 0.6937, G-Loss = 0.7140
# epoch: 1690, D-Loss = 0.6936, G-Loss = 0.7077
# epoch: 1700, D-Loss = 0.6931, G-Loss = 0.6933
# epoch: 1710, D-Loss = 0.6937, G-Loss = 0.7044
# epoch: 1720, D-Loss = 0.6932, G-Loss = 0.6927
# epoch: 1730, D-Loss = 0.6931, G-Loss = 0.7093
# epoch: 1740, D-Loss = 0.6937, G-Loss = 0.7069
# epoch: 1750, D-Loss = 0.6931, G-Loss = 0.7027
# epoch: 1760, D-Loss = 0.6929, G-Loss = 0.7101
# epoch: 1770, D-Loss = 0.6942, G-Loss = 0.7168
# epoch: 1780, D-Loss = 0.6927, G-Loss = 0.7085
# epoch: 1790, D-Loss = 0.6932, G-Loss = 0.7123
# epoch: 1800, D-Loss = 0.6928, G-Loss = 0.6799
# epoch: 1810, D-Loss = 0.6944, G-Loss = 0.7161
# epoch: 1820, D-Loss = 0.6934, G-Loss = 0.7064
# epoch: 1830, D-Loss = 0.6932, G-Loss = 0.7154
# epoch: 1840, D-Loss = 0.6932, G-Loss = 0.6844
# epoch: 1850, D-Loss = 0.6930, G-Loss = 0.6869
# epoch: 1860, D-Loss = 0.6927, G-Loss = 0.6972
# epoch: 1870, D-Loss = 0.6933, G-Loss = 0.7053
# epoch: 1880, D-Loss = 0.6940, G-Loss = 0.7147
# epoch: 1890, D-Loss = 0.6933, G-Loss = 0.7189
# epoch: 1900, D-Loss = 0.6932, G-Loss = 0.7122
# epoch: 1910, D-Loss = 0.6928, G-Loss = 0.7019
# epoch: 1920, D-Loss = 0.6933, G-Loss = 0.6904
# epoch: 1930, D-Loss = 0.6929, G-Loss = 0.6967
# epoch: 1940, D-Loss = 0.6930, G-Loss = 0.6956
# epoch: 1950, D-Loss = 0.6947, G-Loss = 0.7147
# epoch: 1960, D-Loss = 0.6931, G-Loss = 0.6996
# epoch: 1970, D-Loss = 0.6925, G-Loss = 0.6982
# epoch: 1980, D-Loss = 0.6925, G-Loss = 0.6966
# epoch: 1990, D-Loss = 0.6925, G-Loss = 0.6942
# epoch: 2000, D-Loss = 0.6930, G-Loss = 0.6928
# epoch: 2010, D-Loss = 0.6927, G-Loss = 0.7009
# epoch: 2020, D-Loss = 0.6930, G-Loss = 0.6917
# epoch: 2030, D-Loss = 0.6929, G-Loss = 0.7027
# epoch: 2040, D-Loss = 0.6928, G-Loss = 0.7167
# epoch: 2050, D-Loss = 0.6933, G-Loss = 0.7021
# epoch: 2060, D-Loss = 0.6929, G-Loss = 0.6865
# epoch: 2070, D-Loss = 0.6931, G-Loss = 0.6936
# epoch: 2080, D-Loss = 0.6932, G-Loss = 0.7043
# epoch: 2090, D-Loss = 0.6927, G-Loss = 0.6985
# epoch: 2100, D-Loss = 0.6940, G-Loss = 0.6935
# epoch: 2110, D-Loss = 0.6939, G-Loss = 0.7001
# epoch: 2120, D-Loss = 0.6945, G-Loss = 0.7125
# epoch: 2130, D-Loss = 0.6934, G-Loss = 0.6973
# epoch: 2140, D-Loss = 0.6932, G-Loss = 0.7056
# epoch: 2150, D-Loss = 0.6932, G-Loss = 0.7137
# epoch: 2160, D-Loss = 0.6928, G-Loss = 0.7002
# epoch: 2170, D-Loss = 0.6928, G-Loss = 0.7060
# epoch: 2180, D-Loss = 0.6925, G-Loss = 0.6885
# epoch: 2190, D-Loss = 0.6928, G-Loss = 0.7086
# epoch: 2200, D-Loss = 0.6950, G-Loss = 0.7039
# epoch: 2210, D-Loss = 0.6929, G-Loss = 0.7025
# epoch: 2220, D-Loss = 0.6936, G-Loss = 0.6907
# epoch: 2230, D-Loss = 0.6929, G-Loss = 0.6984
# epoch: 2240, D-Loss = 0.6929, G-Loss = 0.7012
# epoch: 2250, D-Loss = 0.6928, G-Loss = 0.7032
# epoch: 2260, D-Loss = 0.6934, G-Loss = 0.6926
# epoch: 2270, D-Loss = 0.6935, G-Loss = 0.7079
# epoch: 2280, D-Loss = 0.6930, G-Loss = 0.6933
# epoch: 2290, D-Loss = 0.6933, G-Loss = 0.7101
# epoch: 2300, D-Loss = 0.6929, G-Loss = 0.6981
# epoch: 2310, D-Loss = 0.6946, G-Loss = 0.7247
# epoch: 2320, D-Loss = 0.6935, G-Loss = 0.6992
# epoch: 2330, D-Loss = 0.6925, G-Loss = 0.7066
# epoch: 2340, D-Loss = 0.6928, G-Loss = 0.7086
# epoch: 2350, D-Loss = 0.6955, G-Loss = 0.7168
# epoch: 2360, D-Loss = 0.6936, G-Loss = 0.6998
# epoch: 2370, D-Loss = 0.6932, G-Loss = 0.7091
# epoch: 2380, D-Loss = 0.6930, G-Loss = 0.6997
# epoch: 2390, D-Loss = 0.6932, G-Loss = 0.6962
# epoch: 2400, D-Loss = 0.6947, G-Loss = 0.6881
# epoch: 2410, D-Loss = 0.6936, G-Loss = 0.6903
# epoch: 2420, D-Loss = 0.6934, G-Loss = 0.7101
# epoch: 2430, D-Loss = 0.6935, G-Loss = 0.7186
# epoch: 2440, D-Loss = 0.6925, G-Loss = 0.6877
# epoch: 2450, D-Loss = 0.6945, G-Loss = 0.7126
# epoch: 2460, D-Loss = 0.6934, G-Loss = 0.7054
# epoch: 2470, D-Loss = 0.6935, G-Loss = 0.7131
# epoch: 2480, D-Loss = 0.6934, G-Loss = 0.6936
# epoch: 2490, D-Loss = 0.6935, G-Loss = 0.7008
# epoch: 2500, D-Loss = 0.6932, G-Loss = 0.7026
# epoch: 2510, D-Loss = 0.6930, G-Loss = 0.7036
# epoch: 2520, D-Loss = 0.6931, G-Loss = 0.7069
# epoch: 2530, D-Loss = 0.6945, G-Loss = 0.7136
# epoch: 2540, D-Loss = 0.6932, G-Loss = 0.6874
# epoch: 2550, D-Loss = 0.6928, G-Loss = 0.6835
# epoch: 2560, D-Loss = 0.6933, G-Loss = 0.7008
# epoch: 2570, D-Loss = 0.6944, G-Loss = 0.7130
# epoch: 2580, D-Loss = 0.6935, G-Loss = 0.6921
# epoch: 2590, D-Loss = 0.6931, G-Loss = 0.7080
# epoch: 2600, D-Loss = 0.6931, G-Loss = 0.7025
# epoch: 2610, D-Loss = 0.6933, G-Loss = 0.6998
# epoch: 2620, D-Loss = 0.6929, G-Loss = 0.6943
# epoch: 2630, D-Loss = 0.6929, G-Loss = 0.7057
# epoch: 2640, D-Loss = 0.6940, G-Loss = 0.7099
# epoch: 2650, D-Loss = 0.6935, G-Loss = 0.7010
# epoch: 2660, D-Loss = 0.6929, G-Loss = 0.6998
# epoch: 2670, D-Loss = 0.6933, G-Loss = 0.7080
# epoch: 2680, D-Loss = 0.6935, G-Loss = 0.6997
# epoch: 2690, D-Loss = 0.6937, G-Loss = 0.7136
# epoch: 2700, D-Loss = 0.6934, G-Loss = 0.7142
# epoch: 2710, D-Loss = 0.6931, G-Loss = 0.7142
# epoch: 2720, D-Loss = 0.6930, G-Loss = 0.6867
# epoch: 2730, D-Loss = 0.6936, G-Loss = 0.7048
# epoch: 2740, D-Loss = 0.6939, G-Loss = 0.6950
# epoch: 2750, D-Loss = 0.6929, G-Loss = 0.7147
# epoch: 2760, D-Loss = 0.6932, G-Loss = 0.6854
# epoch: 2770, D-Loss = 0.6930, G-Loss = 0.7098
# epoch: 2780, D-Loss = 0.6918, G-Loss = 0.6889
# epoch: 2790, D-Loss = 0.6925, G-Loss = 0.7000
# epoch: 2800, D-Loss = 0.6931, G-Loss = 0.6976
# epoch: 2810, D-Loss = 0.6929, G-Loss = 0.7028
# epoch: 2820, D-Loss = 0.6942, G-Loss = 0.6941
# epoch: 2830, D-Loss = 0.6934, G-Loss = 0.7009
# epoch: 2840, D-Loss = 0.6938, G-Loss = 0.7067
# epoch: 2850, D-Loss = 0.6935, G-Loss = 0.7044
# epoch: 2860, D-Loss = 0.6929, G-Loss = 0.6950
# epoch: 2870, D-Loss = 0.6932, G-Loss = 0.7318
# epoch: 2880, D-Loss = 0.6933, G-Loss = 0.6872
# epoch: 2890, D-Loss = 0.6942, G-Loss = 0.7151
# epoch: 2900, D-Loss = 0.6942, G-Loss = 0.7220
# epoch: 2910, D-Loss = 0.6931, G-Loss = 0.6929
# epoch: 2920, D-Loss = 0.6933, G-Loss = 0.6934
# epoch: 2930, D-Loss = 0.6939, G-Loss = 0.7146
# epoch: 2940, D-Loss = 0.6932, G-Loss = 0.7052
# epoch: 2950, D-Loss = 0.6947, G-Loss = 0.7077
# epoch: 2960, D-Loss = 0.6935, G-Loss = 0.7027
# epoch: 2970, D-Loss = 0.6931, G-Loss = 0.7041
# epoch: 2980, D-Loss = 0.6935, G-Loss = 0.7112
# epoch: 2990, D-Loss = 0.6934, G-Loss = 0.7023

# %% [markdown]
# # _6_. 데이터 분포 그려 보기
# * 역시나, 여기서도 model이기 때문에 predict해야 분포가 나온다.
# * 분포 2차원으로 그려주어야 함에 주의한다. 따라서 scatter 사용해야 한다. sns kdeplot 아니다. 일변량 분포.

# %%
# 데이터 분포
z = getNoise(m = real_data.shape[0], n=g_input)
fake_data = G.predict(z) # predict해야 data 나옴.

plt.figure(figsize=(10, 7))
# sns.set_style('whitegrid')
# sns.kdeplot(real_data[:, 0], color='blue', bw=0.3, label='REAL data')
# sns.kdeplot(fake_data[:, 0], color='red', bw=0.3, label='FAKE data')
plt.scatter(real_data[:, 0], real_data[:, 1], color='blue', s=5, label='REAL data')
plt.scatter(fake_data[:, 0], fake_data[:, 1], color='red', s=5, label='FAKE data')
plt.legend()
plt.title('REAL vs. FAKE distribution')
plt.show()

# %%
# 실제 데이터 넣어서 discriminator가 어떻게 예측하는지 보기
discriminate_real_values = D.predict(real_data)
discriminate_fake_values = D.predict(fake_data)

plt.figure(figsize=(8, 5))
plt.plot(discriminate_real_values, label='Discriminated Real Data')
plt.plot(discriminate_fake_values, label='Discriminated Fake Data', color='red')
plt.title("Discriminator vs. Generator")
plt.legend()
plt.show()

# %%
# GAN model 구조 확인
print(GAN.summary())
print(G.summary())
print(D.summary())
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 16)]              0
# _________________________________________________________________
# model_1 (Model)              (None, 2)                 2434
# _________________________________________________________________
# model (Model)                (None, 1)                 513
# =================================================================
# Total params: 2,947
# Trainable params: 2,434
# Non-trainable params: 513
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 16)]              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               2176
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 2,434
# Trainable params: 2,434
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 2)]               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               384
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,026
# Trainable params: 513
# Non-trainable params: 513
# _________________________________________________________________
# None

# %% [markdown]
# ### 제대로 안 나온 경우

# %%
# # 데이터 분포
# z = getNoise(m = real_data.shape[0], n=g_input)
# fake_data = G.predict(z) # predict해야 data 나옴.

# plt.figure(figsize=(10, 7))
# # sns.set_style('whitegrid')
# # sns.kdeplot(real_data[:, 0], color='blue', bw=0.3, label='REAL data')
# # sns.kdeplot(fake_data[:, 0], color='red', bw=0.3, label='FAKE data')
# plt.scatter(real_data[:, 0], real_data[:, 1], color='blue', s=5, label='REAL data')
# plt.scatter(fake_data[:, 0], fake_data[:, 1], color='red', s=5, label='FAKE data')
# plt.legend()
# plt.title('REAL vs. FAKE distribution')
# plt.show()
