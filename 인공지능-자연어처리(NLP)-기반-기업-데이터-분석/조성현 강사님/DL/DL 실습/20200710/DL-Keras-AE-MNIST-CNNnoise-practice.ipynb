# %%
# module import
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Conv2DTranspose
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
import pickle
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import numpy as np

# %%
# 경로 설정
root_path = "/content/drive/My Drive/멀티캠퍼스/[혁신성장] 인공지능 자연어처리 기반/[강의]/조성현 강사님"
data_path = f"{root_path}/dataset"

# %%
# 데이터 로드
with open(f"{data_path}/mnist.pickle", 'rb') as f:
    data = pickle.load(f)

# %%
# 데이터 확인
dir(data)
# Out:
# ['DESCR', 'categories', 'data', 'details', 'feature_names', 'target', 'url']

# %% [markdown]
# # _1_. Sigmoid, BinaryCrossentropy

# %%
# 입력 데이터 생성
X_train = mnist.data[:3000, :] / 255
X_test = mnist.data[3000:3100, :] / 255

plt.imshow(mnist.data[101].reshape(28, 28), cmap=plt.cm.bone)
plt.show()
plt.imshow(X_train[101].reshape(28, 28), cmap=plt.cm.bone)
plt.show()

# %%
# 노이즈 삽입
X_train_n = X_train + 0.3*np.random.normal(size=X_train.shape)
X_test_n = X_test + 0.3*np.random.normal(size=X_test.shape)
print(f"노이즈 삽입 전: {X_train.shape}, 노이즈 삽입 후: {X_train_n.shape}")

# 확인
plt.imshow(X_train_n[101].reshape(28, 28), cmap=plt.cm.bone)
plt.show()
# Out:
# 노이즈 삽입 전: (3000, 784), 노이즈 삽입 후: (3000, 784)

# %%
# clip
X_train_n_clipped = np.clip(X_train_n, 0., 1.)
X_test_n_clipped = np.clip(X_test_n, 0., 1.)

# %%
# CNN에 주입하기 위해 차원 증가
print("훈련 데이터")
X_train = X_train.reshape(-1, 28, 28)
X_test = X_test.reshape(-1, 28, 28)
print(f"3차원 변환 후: {X_train.shape}")
print(f"3차원 변환 후: {X_test.shape}")
print("")
print("테스트 데이터")
X_train_n = X_train_n_clipped.reshape(-1, 28, 28)
X_test_n = X_test_n_clipped.reshape(-1, 28, 28)
print(f"3차원 변환 전: {X_train_n_clipped.shape}, 후: {X_train.shape}")
print(f"3차원 변환 전: {X_test_n_clipped.shape}, 후: {X_test.shape}")
# Out:
# 훈련 데이터
# 3차원 변환 후: (3000, 28, 28)
# 3차원 변환 후: (100, 28, 28)
#
# 테스트 데이터
# 3차원 변환 전: (3000, 784), 후: (3000, 28, 28)
# 3차원 변환 전: (100, 784), 후: (100, 28, 28)

# %%
# CNN 파라미터: 노이즈 데이터를 주입할 것이기 때문에 노이즈로!!
n_height = X_train_n.shape[1] # 28
n_width = X_train_n.shape[2]
n_channel = 1 # 흑백 이미지

# %%
# 오토인코더 레이어 구성
x_Input = Input(batch_shape=(None, n_height, n_width, n_channel))

# 인코더
e_conv = Conv2D(filters=10, kernel_size=(3, 3), strides=1, padding='SAME', activation='relu')(x_Input) # same: 28*28
e_pool = MaxPooling2D(pool_size=(2,2), strides=1, padding='SAME')(e_conv) # same! 28 x 28

# 디코더
d_conv = Conv2DTranspose(filters=10, kernel_size=(3, 3), strides=1, padding='SAME', activation='relu')(e_pool) # 아마 same이니까 28*28
x_Output = Conv2D(filters=1, kernel_size=(3, 3), strides=1, padding='SAME', activation='sigmoid')(d_conv) # 0~1 사이 값으로 뽑아내야 하므로 sigmoid!

# %%
# 모델 구성
model = Model(x_Input, x_Output)
model.compile(loss='binary_crossentropy', optimizer=Adam(lr=0.005)) # 이거 그냥 전에 sigmoid여서?
print("====== 모델 전체 구조 =====")
print(model.summary())
# Out:
# ====== 모델 전체 구조 =====
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 28, 28, 10)        100
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 28, 28, 10)        0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 28, 28, 10)        910
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 28, 28, 1)         91
# =================================================================
# Total params: 1,101
# Trainable params: 1,101
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# 4차원에 맞추기 위해 채널 축 추가
X_train_n = X_train_n[:, :, :, np.newaxis]

# 오토인코더 학습: X_train과 X_train_n을 맞춘다.
hist = model.fit(X_train_n, X_train, epochs=100, batch_size=300, shuffle=True)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 5s 461ms/step - loss: 0.5708
# Epoch 2/100
# 10/10 [==============================] - 4s 433ms/step - loss: 0.3807
# Epoch 3/100
# 10/10 [==============================] - 4s 377ms/step - loss: 0.2645
# Epoch 4/100
# 10/10 [==============================] - 4s 382ms/step - loss: 0.2133
# Epoch 5/100
# 10/10 [==============================] - 4s 362ms/step - loss: 0.1796
# Epoch 6/100
# 10/10 [==============================] - 4s 365ms/step - loss: 0.1572
# Epoch 7/100
# 10/10 [==============================] - 4s 375ms/step - loss: 0.1414
# Epoch 8/100
# 10/10 [==============================] - 4s 370ms/step - loss: 0.1155
# Epoch 9/100
# 10/10 [==============================] - 4s 387ms/step - loss: 0.0965
# Epoch 10/100
# 10/10 [==============================] - 4s 361ms/step - loss: 0.0908
# Epoch 11/100
# 10/10 [==============================] - 4s 372ms/step - loss: 0.0875
# Epoch 12/100
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0862
# Epoch 13/100
# 10/10 [==============================] - 4s 368ms/step - loss: 0.0854
# Epoch 14/100
# 10/10 [==============================] - 4s 375ms/step - loss: 0.0847
# Epoch 15/100
# 10/10 [==============================] - 4s 363ms/step - loss: 0.0842
# Epoch 16/100
# 10/10 [==============================] - 4s 392ms/step - loss: 0.0838
# Epoch 17/100
# 10/10 [==============================] - 4s 402ms/step - loss: 0.0835
# Epoch 18/100
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0832
# Epoch 19/100
# 10/10 [==============================] - 4s 392ms/step - loss: 0.0830
# Epoch 20/100
# 10/10 [==============================] - 4s 382ms/step - loss: 0.0828
# Epoch 21/100
# 10/10 [==============================] - 4s 392ms/step - loss: 0.0826
# Epoch 22/100
# 10/10 [==============================] - 4s 389ms/step - loss: 0.0824
# Epoch 23/100
# 10/10 [==============================] - 4s 428ms/step - loss: 0.0823
# Epoch 24/100
# 10/10 [==============================] - 4s 374ms/step - loss: 0.0822
# Epoch 25/100
# 10/10 [==============================] - 4s 377ms/step - loss: 0.0822
# Epoch 26/100
# 10/10 [==============================] - 4s 388ms/step - loss: 0.0820
# Epoch 27/100
# 10/10 [==============================] - 4s 391ms/step - loss: 0.0819
# Epoch 28/100
# 10/10 [==============================] - 4s 394ms/step - loss: 0.0818
# Epoch 29/100
# 10/10 [==============================] - 4s 433ms/step - loss: 0.0817
# Epoch 30/100
# 10/10 [==============================] - 4s 413ms/step - loss: 0.0817
# Epoch 31/100
# 10/10 [==============================] - 4s 381ms/step - loss: 0.0816
# Epoch 32/100
# 10/10 [==============================] - 4s 354ms/step - loss: 0.0816
# Epoch 33/100
# 10/10 [==============================] - 4s 384ms/step - loss: 0.0815
# Epoch 34/100
# 10/10 [==============================] - 4s 388ms/step - loss: 0.0814
# Epoch 35/100
# 10/10 [==============================] - 4s 353ms/step - loss: 0.0814
# Epoch 36/100
# 10/10 [==============================] - 4s 355ms/step - loss: 0.0813
# Epoch 37/100
# 10/10 [==============================] - 4s 360ms/step - loss: 0.0813
# Epoch 38/100
# 10/10 [==============================] - 4s 366ms/step - loss: 0.0813
# Epoch 39/100
# 10/10 [==============================] - 4s 372ms/step - loss: 0.0812
# Epoch 40/100
# 10/10 [==============================] - 4s 435ms/step - loss: 0.0812
# Epoch 41/100
# 10/10 [==============================] - 4s 402ms/step - loss: 0.0812
# Epoch 42/100
# 10/10 [==============================] - 4s 355ms/step - loss: 0.0811
# Epoch 43/100
# 10/10 [==============================] - 4s 366ms/step - loss: 0.0810
# Epoch 44/100
# 10/10 [==============================] - 4s 367ms/step - loss: 0.0810
# Epoch 45/100
# 10/10 [==============================] - 4s 382ms/step - loss: 0.0810
# Epoch 46/100
# 10/10 [==============================] - 4s 399ms/step - loss: 0.0809
# Epoch 47/100
# 10/10 [==============================] - 4s 377ms/step - loss: 0.0809
# Epoch 48/100
# 10/10 [==============================] - 4s 371ms/step - loss: 0.0809
# Epoch 49/100
# 10/10 [==============================] - 4s 366ms/step - loss: 0.0808
# Epoch 50/100
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0808
# Epoch 51/100
# 10/10 [==============================] - 4s 355ms/step - loss: 0.0807
# Epoch 52/100
# 10/10 [==============================] - 3s 349ms/step - loss: 0.0807
# Epoch 53/100
# 10/10 [==============================] - 4s 362ms/step - loss: 0.0807
# Epoch 54/100
# 10/10 [==============================] - 4s 362ms/step - loss: 0.0807
# Epoch 55/100
# 10/10 [==============================] - 4s 364ms/step - loss: 0.0806
# Epoch 56/100
# 10/10 [==============================] - 4s 355ms/step - loss: 0.0806
# Epoch 57/100
# 10/10 [==============================] - 4s 358ms/step - loss: 0.0805
# Epoch 58/100
# 10/10 [==============================] - 4s 355ms/step - loss: 0.0805
# Epoch 59/100
# 10/10 [==============================] - 4s 355ms/step - loss: 0.0805
# Epoch 60/100
# 10/10 [==============================] - 4s 352ms/step - loss: 0.0805
# Epoch 61/100
# 10/10 [==============================] - 4s 375ms/step - loss: 0.0804
# Epoch 62/100
# 10/10 [==============================] - 4s 373ms/step - loss: 0.0804
# Epoch 63/100
# 10/10 [==============================] - 4s 371ms/step - loss: 0.0804
# Epoch 64/100
# 10/10 [==============================] - 4s 365ms/step - loss: 0.0804
# Epoch 65/100
# 10/10 [==============================] - 4s 357ms/step - loss: 0.0803
# Epoch 66/100
# 10/10 [==============================] - 4s 360ms/step - loss: 0.0803
# Epoch 67/100
# 10/10 [==============================] - 4s 354ms/step - loss: 0.0803
# Epoch 68/100
# 10/10 [==============================] - 4s 369ms/step - loss: 0.0802
# Epoch 69/100
# 10/10 [==============================] - 4s 384ms/step - loss: 0.0802
# Epoch 70/100
# 10/10 [==============================] - 4s 381ms/step - loss: 0.0802
# Epoch 71/100
# 10/10 [==============================] - 4s 359ms/step - loss: 0.0801
# Epoch 72/100
# 10/10 [==============================] - 4s 376ms/step - loss: 0.0801
# Epoch 73/100
# 10/10 [==============================] - 4s 357ms/step - loss: 0.0801
# Epoch 74/100
# 10/10 [==============================] - 4s 368ms/step - loss: 0.0801
# Epoch 75/100
# 10/10 [==============================] - 4s 371ms/step - loss: 0.0801
# Epoch 76/100
# 10/10 [==============================] - 4s 369ms/step - loss: 0.0800
# Epoch 77/100
# 10/10 [==============================] - 4s 374ms/step - loss: 0.0800
# Epoch 78/100
# 10/10 [==============================] - 4s 361ms/step - loss: 0.0799
# Epoch 79/100
# 10/10 [==============================] - 4s 363ms/step - loss: 0.0798
# Epoch 80/100
# 10/10 [==============================] - 4s 375ms/step - loss: 0.0798
# Epoch 81/100
# 10/10 [==============================] - 4s 405ms/step - loss: 0.0798
# Epoch 82/100
# 10/10 [==============================] - 4s 374ms/step - loss: 0.0798
# Epoch 83/100
# 10/10 [==============================] - 4s 382ms/step - loss: 0.0798
# Epoch 84/100
# 10/10 [==============================] - 4s 367ms/step - loss: 0.0797
# Epoch 85/100
# 10/10 [==============================] - 4s 382ms/step - loss: 0.0797
# Epoch 86/100
# 10/10 [==============================] - 4s 408ms/step - loss: 0.0797
# Epoch 87/100
# 10/10 [==============================] - 4s 389ms/step - loss: 0.0797
# Epoch 88/100
# 10/10 [==============================] - 4s 409ms/step - loss: 0.0796
# Epoch 89/100
# 10/10 [==============================] - 4s 365ms/step - loss: 0.0796
# Epoch 90/100
# 10/10 [==============================] - 4s 377ms/step - loss: 0.0797
# Epoch 91/100
# 10/10 [==============================] - 4s 396ms/step - loss: 0.0796
# Epoch 92/100
# 10/10 [==============================] - 4s 392ms/step - loss: 0.0795
# Epoch 93/100
# 10/10 [==============================] - 5s 475ms/step - loss: 0.0795
# Epoch 94/100
# 10/10 [==============================] - 4s 406ms/step - loss: 0.0796
# Epoch 95/100
# 10/10 [==============================] - 4s 410ms/step - loss: 0.0795
# Epoch 96/100
# 10/10 [==============================] - 4s 398ms/step - loss: 0.0795
# Epoch 97/100
# 10/10 [==============================] - 4s 380ms/step - loss: 0.0794
# Epoch 98/100
# 10/10 [==============================] - 4s 384ms/step - loss: 0.0794
# Epoch 99/100
# 10/10 [==============================] - 4s 394ms/step - loss: 0.0794
# Epoch 100/100
# 10/10 [==============================] - 4s 399ms/step - loss: 0.0794

# %%
# plot loss
plt.plot(hist.history['loss'], label='Train Loss')
plt.title('Loss Trajectory')
plt.legend()
plt.show()

# %%
# 화면에 이미지 그림
def showImage(x):
    n = 0
    for k in range(2): # figure 2개에 10개 나눠 그림 그리기 위해 range(2)
        plt.figure(figsize=(8, 2))
        for i in range(5):
            ax = plt.subplot(1, 5, i+1)
            plt.imshow(x[n].reshape(28, 28))
            plt.gray()
            ax.get_xaxis().set_visible(False)
            ax.get_yaxis().set_visible(False)
            n += 1
        plt.show()

# %%
# 노이즈가 추가된 데이터 10개
print("잡음이 삽입된 테스트 데이터 10개")
showImage(X_test_n)
# Out:
# 잡음이 삽입된 테스트 데이터 10개

# %%
# 오토인코더 모델에 통과시켜서 잡음 제거
print(f"원래 테스트 데이터: {X_test_n.shape}")
X_test_n = X_test_n.reshape(-1, 28, 28)
X_test_n = X_test_n[:, :, :, np.newaxis] # 채널 축 추가
print(f"모델에 넣기 위해 차원을 변경한 데이터: {X_test_n.shape}")
# Out:
# 원래 테스트 데이터: (100, 28, 28)
# 모델에 넣기 위해 차원을 변경한 데이터: (100, 28, 28, 1)

# %%
X_test_detected = model.predict(X_test_n)
plt.imshow(X_test_n[0].reshape(28, 28))
plt.show()
plt.imshow(X_test_detected[0].reshape(28, 28))
plt.show()

# %%
# 잡음을 제거한 테스트 데이터 10개
print("잡음을 제거한 테스트 데이터 10개")
showImage(X_test_detected)
# Out:
# 잡음을 제거한 테스트 데이터 10개

# %% [markdown]
# ## 모델 shape 확인

# %%
test = Model(x_Input, e_conv)
test.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 10)        100
# =================================================================
# Total params: 100
# Trainable params: 100
# Non-trainable params: 0
# _________________________________________________________________

# %%
test_1 = Model(x_Input, e_pool)
test_1.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 10)        100
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 28, 28, 10)        0
# =================================================================
# Total params: 100
# Trainable params: 100
# Non-trainable params: 0
# _________________________________________________________________

# %%
test_2 = Model(x_Input, d_conv)
test_2.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 10)        100
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 28, 28, 10)        0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 28, 28, 10)        910
# =================================================================
# Total params: 1,010
# Trainable params: 1,010
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # _2_. Linear, MSE

# %%
# 입력 데이터 생성
X_train = mnist.data[:3000, :] / 255
X_test = mnist.data[3000:3100, :] / 255
plt.imshow(X_train[102].reshape(28, 28), cmap=plt.cm.bone)
plt.show()

# 노이즈 삽입
X_train_n = X_train + 0.3*np.random.normal(size=X_train.shape)
X_test_n = X_test + 0.3*np.random.normal(size=X_test.shape)
print(f"노이즈 삽입 전: {X_train.shape}, 노이즈 삽입 후: {X_train_n.shape}")

# 확인
plt.imshow(X_train_n[102].reshape(28, 28), cmap=plt.cm.bone)
plt.show()

# clip
X_train_n_clipped = np.clip(X_train_n, 0., 1.)
X_test_n_clipped = np.clip(X_test_n, 0., 1.)

# CNN에 주입하기 위해 차원 증가
print("훈련 데이터")
X_train = X_train.reshape(-1, 28, 28)
X_test = X_test.reshape(-1, 28, 28)
print(f"3차원 변환 후: {X_train.shape}")
print(f"3차원 변환 후: {X_test.shape}")
print("")
print("테스트 데이터")
X_train_n = X_train_n_clipped.reshape(-1, 28, 28)
X_test_n = X_test_n_clipped.reshape(-1, 28, 28)
print(f"3차원 변환 전: {X_train_n_clipped.shape}, 후: {X_train.shape}")
print(f"3차원 변환 전: {X_test_n_clipped.shape}, 후: {X_test.shape}")

# CNN 파라미터: 노이즈 데이터를 주입할 것이기 때문에 노이즈로!!
n_height = X_train_n.shape[1] # 28
n_width = X_train_n.shape[2]
n_channel = 1 # 흑백 이미지

# 오토인코더 레이어 구성
x_Input = Input(batch_shape=(None, n_height, n_width, n_channel))

# 인코더
e_conv = Conv2D(filters=10, kernel_size=(3, 3), strides=1, padding='SAME', activation='relu')(x_Input) # same: 28*28
e_pool = MaxPooling2D(pool_size=(2,2), strides=1, padding='SAME')(e_conv) # same! 28 x 28

# 디코더
d_conv = Conv2DTranspose(filters=10, kernel_size=(3, 3), strides=1, padding='SAME', activation='relu')(e_pool) # 아마 same이니까 28*28
x_Output = Conv2D(filters=1, kernel_size=(3, 3), strides=1, padding='SAME', activation='linear')(d_conv) 

# 모델 구성
model = Model(x_Input, x_Output)
model.compile(loss='mse', optimizer=Adam(lr=0.005)) # 이거 그냥 전에 sigmoid여서?
print("====== 모델 전체 구조 =====")
print(model.summary())

# 4차원에 맞추기 위해 채널 축 추가
X_train_n = X_train_n[:, :, :, np.newaxis]

# 오토인코더 학습: X_train과 X_train_n을 맞춘다.
hist = model.fit(X_train_n, X_train, epochs=100, batch_size=300, shuffle=True)

# plot loss
plt.plot(hist.history['loss'], label='Train Loss')
plt.title('Loss Trajectory')
plt.legend()
plt.show()

# 화면에 이미지 그림
def showImage(x):
    n = 0
    for k in range(2): # figure 2개에 10개 나눠 그림 그리기 위해 range(2)
        plt.figure(figsize=(8, 2))
        for i in range(5):
            ax = plt.subplot(1, 5, i+1)
            plt.imshow(x[n].reshape(28, 28))
            plt.gray()
            ax.get_xaxis().set_visible(False)
            ax.get_yaxis().set_visible(False)
            n += 1
        plt.show()

# 노이즈가 추가된 데이터 10개
print("잡음이 삽입된 테스트 데이터 10개")
showImage(X_test_n)

# 오토인코더 모델에 통과시켜서 잡음 제거
print(f"원래 테스트 데이터: {X_test_n.shape}")
X_test_n = X_test_n.reshape(-1, 28, 28)
X_test_n = X_test_n[:, :, :, np.newaxis] # 채널 축 추가
print(f"모델에 넣기 위해 차원을 변경한 데이터: {X_test_n.shape}")

# 잡음 제거
X_test_detected = model.predict(X_test_n)
plt.imshow(X_test_n[0].reshape(28, 28))
plt.show()
plt.imshow(X_test_detected[0].reshape(28, 28))
plt.show()

# 잡음을 제거한 테스트 데이터 10개
print("잡음을 제거한 테스트 데이터 10개")
showImage(X_test_detected)
# Out:
# 노이즈 삽입 전: (3000, 784), 노이즈 삽입 후: (3000, 784)
# 훈련 데이터
# 3차원 변환 후: (3000, 28, 28)
# 3차원 변환 후: (100, 28, 28)
#
# 테스트 데이터
# 3차원 변환 전: (3000, 784), 후: (3000, 28, 28)
# 3차원 변환 전: (100, 784), 후: (100, 28, 28)
# ====== 모델 전체 구조 =====
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 28, 28, 10)        100
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 28, 28, 10)        0
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 28, 28, 10)        910
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 28, 28, 1)         91
# =================================================================
# Total params: 1,101
# Trainable params: 1,101
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 10/10 [==============================] - 3s 338ms/step - loss: 0.0488
# Epoch 2/100
# 10/10 [==============================] - 4s 354ms/step - loss: 0.0182
# Epoch 3/100
# 10/10 [==============================] - 3s 346ms/step - loss: 0.0142
# Epoch 4/100
# 10/10 [==============================] - 3s 343ms/step - loss: 0.0115
# Epoch 5/100
# 10/10 [==============================] - 3s 336ms/step - loss: 0.0101
# Epoch 6/100
# 10/10 [==============================] - 3s 334ms/step - loss: 0.0094
# Epoch 7/100
# 10/10 [==============================] - 4s 351ms/step - loss: 0.0089
# Epoch 8/100
# 10/10 [==============================] - 4s 364ms/step - loss: 0.0085
# Epoch 9/100
# 10/10 [==============================] - 3s 338ms/step - loss: 0.0083
# Epoch 10/100
# 10/10 [==============================] - 3s 339ms/step - loss: 0.0081
# Epoch 11/100
# 10/10 [==============================] - 4s 365ms/step - loss: 0.0079
# Epoch 12/100
# 10/10 [==============================] - 3s 336ms/step - loss: 0.0078
# Epoch 13/100
# 10/10 [==============================] - 3s 347ms/step - loss: 0.0077
# Epoch 14/100
# 10/10 [==============================] - 3s 338ms/step - loss: 0.0076
# Epoch 15/100
# 10/10 [==============================] - 3s 340ms/step - loss: 0.0075
# Epoch 16/100
# 10/10 [==============================] - 3s 343ms/step - loss: 0.0075
# Epoch 17/100
# 10/10 [==============================] - 3s 337ms/step - loss: 0.0074
# Epoch 18/100
# 10/10 [==============================] - 3s 334ms/step - loss: 0.0073
# Epoch 19/100
# 10/10 [==============================] - 3s 334ms/step - loss: 0.0073
# Epoch 20/100
# 10/10 [==============================] - 3s 333ms/step - loss: 0.0072
# Epoch 21/100
# 10/10 [==============================] - 3s 333ms/step - loss: 0.0072
# Epoch 22/100
# 10/10 [==============================] - 3s 339ms/step - loss: 0.0071
# Epoch 23/100
# 10/10 [==============================] - 3s 346ms/step - loss: 0.0071
# Epoch 24/100
# 10/10 [==============================] - 3s 336ms/step - loss: 0.0070
# Epoch 25/100
# 10/10 [==============================] - 3s 337ms/step - loss: 0.0070
# Epoch 26/100
# 10/10 [==============================] - 3s 334ms/step - loss: 0.0069
# Epoch 27/100
# 10/10 [==============================] - 3s 339ms/step - loss: 0.0069
# Epoch 28/100
# 10/10 [==============================] - 3s 335ms/step - loss: 0.0069
# Epoch 29/100
# 10/10 [==============================] - 3s 334ms/step - loss: 0.0068
# Epoch 30/100
# 10/10 [==============================] - 3s 344ms/step - loss: 0.0068
# Epoch 31/100
# 10/10 [==============================] - 3s 349ms/step - loss: 0.0067
# Epoch 32/100
# 10/10 [==============================] - 3s 342ms/step - loss: 0.0067
# Epoch 33/100
# 10/10 [==============================] - 3s 337ms/step - loss: 0.0067
# Epoch 34/100
# 10/10 [==============================] - 3s 334ms/step - loss: 0.0066
# Epoch 35/100
# 10/10 [==============================] - 3s 332ms/step - loss: 0.0066
# Epoch 36/100
# 10/10 [==============================] - 3s 342ms/step - loss: 0.0065
# Epoch 37/100
# 10/10 [==============================] - 3s 330ms/step - loss: 0.0065
# Epoch 38/100
# 10/10 [==============================] - 3s 332ms/step - loss: 0.0065
# Epoch 39/100
# 10/10 [==============================] - 3s 345ms/step - loss: 0.0064
# Epoch 40/100
# 10/10 [==============================] - 3s 349ms/step - loss: 0.0064
# Epoch 41/100
# 10/10 [==============================] - 4s 362ms/step - loss: 0.0064
# Epoch 42/100
# 10/10 [==============================] - 3s 342ms/step - loss: 0.0064
# Epoch 43/100
# 10/10 [==============================] - 3s 336ms/step - loss: 0.0063
# Epoch 44/100
# 10/10 [==============================] - 3s 348ms/step - loss: 0.0063
# Epoch 45/100
# 10/10 [==============================] - 3s 333ms/step - loss: 0.0063
# Epoch 46/100
# 10/10 [==============================] - 3s 350ms/step - loss: 0.0063
# Epoch 47/100
# 10/10 [==============================] - 3s 345ms/step - loss: 0.0063
# Epoch 48/100
# 10/10 [==============================] - 3s 335ms/step - loss: 0.0062
# Epoch 49/100
# 10/10 [==============================] - 3s 344ms/step - loss: 0.0063
# Epoch 50/100
# 10/10 [==============================] - 3s 335ms/step - loss: 0.0062
# Epoch 51/100
# 10/10 [==============================] - 4s 351ms/step - loss: 0.0062
# Epoch 52/100
# 10/10 [==============================] - 3s 338ms/step - loss: 0.0061
# Epoch 53/100
# 10/10 [==============================] - 3s 340ms/step - loss: 0.0062
# Epoch 54/100
# 10/10 [==============================] - 3s 344ms/step - loss: 0.0061
# Epoch 55/100
# 10/10 [==============================] - 3s 343ms/step - loss: 0.0061
# Epoch 56/100
# 10/10 [==============================] - 4s 351ms/step - loss: 0.0062
# Epoch 57/100
# 10/10 [==============================] - 3s 349ms/step - loss: 0.0062
# Epoch 58/100
# 10/10 [==============================] - 3s 343ms/step - loss: 0.0061
# Epoch 59/100
# 10/10 [==============================] - 3s 345ms/step - loss: 0.0061
# Epoch 60/100
# 10/10 [==============================] - 3s 338ms/step - loss: 0.0060
# Epoch 61/100
# 10/10 [==============================] - 3s 331ms/step - loss: 0.0062
# Epoch 62/100
# 10/10 [==============================] - 4s 352ms/step - loss: 0.0061
# Epoch 63/100
# 10/10 [==============================] - 4s 354ms/step - loss: 0.0060
# Epoch 64/100
# 10/10 [==============================] - 3s 334ms/step - loss: 0.0060
# Epoch 65/100
# 10/10 [==============================] - 3s 339ms/step - loss: 0.0060
# Epoch 66/100
# 10/10 [==============================] - 3s 334ms/step - loss: 0.0059
# Epoch 67/100
# 10/10 [==============================] - 3s 333ms/step - loss: 0.0059
# Epoch 68/100
# 10/10 [==============================] - 3s 333ms/step - loss: 0.0060
# Epoch 69/100
# 10/10 [==============================] - 3s 341ms/step - loss: 0.0059
# Epoch 70/100
# 10/10 [==============================] - 4s 365ms/step - loss: 0.0060
# Epoch 71/100
# 10/10 [==============================] - 3s 341ms/step - loss: 0.0059
# Epoch 72/100
# 10/10 [==============================] - 3s 333ms/step - loss: 0.0060
# Epoch 73/100
# 10/10 [==============================] - 3s 343ms/step - loss: 0.0060
# Epoch 74/100
# 10/10 [==============================] - 3s 338ms/step - loss: 0.0060
# Epoch 75/100
# 10/10 [==============================] - 3s 335ms/step - loss: 0.0059
# Epoch 76/100
# 10/10 [==============================] - 3s 331ms/step - loss: 0.0059
# Epoch 77/100
# 10/10 [==============================] - 4s 354ms/step - loss: 0.0059
# Epoch 78/100
# 10/10 [==============================] - 3s 342ms/step - loss: 0.0058
# Epoch 79/100
# 10/10 [==============================] - 3s 349ms/step - loss: 0.0058
# Epoch 80/100
# 10/10 [==============================] - 3s 332ms/step - loss: 0.0059
# Epoch 81/100
# 10/10 [==============================] - 3s 340ms/step - loss: 0.0059
# Epoch 82/100
# 10/10 [==============================] - 3s 339ms/step - loss: 0.0058
# Epoch 83/100
# 10/10 [==============================] - 3s 346ms/step - loss: 0.0059
# Epoch 84/100
# 10/10 [==============================] - 3s 339ms/step - loss: 0.0059
# Epoch 85/100
# 10/10 [==============================] - 3s 349ms/step - loss: 0.0058
# Epoch 86/100
# 10/10 [==============================] - 3s 349ms/step - loss: 0.0058
# Epoch 87/100
# 10/10 [==============================] - 3s 341ms/step - loss: 0.0058
# Epoch 88/100
# 10/10 [==============================] - 4s 364ms/step - loss: 0.0058
# Epoch 89/100
# 10/10 [==============================] - 4s 359ms/step - loss: 0.0058
# Epoch 90/100
# 10/10 [==============================] - 3s 346ms/step - loss: 0.0058
# Epoch 91/100
# 10/10 [==============================] - 4s 364ms/step - loss: 0.0059
# Epoch 92/100
# 10/10 [==============================] - 4s 387ms/step - loss: 0.0058
# Epoch 93/100
# 10/10 [==============================] - 6s 615ms/step - loss: 0.0060
# Epoch 94/100
# 10/10 [==============================] - 4s 355ms/step - loss: 0.0058
# Epoch 95/100
# 10/10 [==============================] - 4s 375ms/step - loss: 0.0057
# Epoch 96/100
# 10/10 [==============================] - 4s 353ms/step - loss: 0.0057
# Epoch 97/100
# 10/10 [==============================] - 4s 375ms/step - loss: 0.0058
# Epoch 98/100
# 10/10 [==============================] - 4s 363ms/step - loss: 0.0058
# Epoch 99/100
# 10/10 [==============================] - 4s 353ms/step - loss: 0.0058
# Epoch 100/100
# 10/10 [==============================] - 4s 372ms/step - loss: 0.0057
# 잡음이 삽입된 테스트 데이터 10개
# 원래 테스트 데이터: (100, 28, 28)
# 모델에 넣기 위해 차원을 변경한 데이터: (100, 28, 28, 1)
# 잡음을 제거한 테스트 데이터 10개

# %% [markdown]
# # _3_. 어떤 층이 잡음 제거하는지 보자.

# %%
# 데이터 가져 오기
mnist = data

# 입력 데이터 생성
X_train = mnist.data[:3000, :] / 255
X_test = mnist.data[3000:3100, :] / 255
plt.imshow(X_train[102].reshape(28, 28), cmap=plt.cm.bone)
plt.show()

# 노이즈 삽입
X_train_n = X_train + 0.3*np.random.normal(size=X_train.shape)
X_test_n = X_test + 0.3*np.random.normal(size=X_test.shape)
print(f"노이즈 삽입 전: {X_train.shape}, 노이즈 삽입 후: {X_train_n.shape}")

# 확인
plt.imshow(X_train_n[102].reshape(28, 28), cmap=plt.cm.bone)
plt.show()

# clip
X_train_n_clipped = np.clip(X_train_n, 0., 1.)
X_test_n_clipped = np.clip(X_test_n, 0., 1.)

# CNN에 주입하기 위해 차원 증가
print("훈련 데이터")
X_train = X_train.reshape(-1, 28, 28)
X_test = X_test.reshape(-1, 28, 28)
print(f"3차원 변환 후: {X_train.shape}")
print(f"3차원 변환 후: {X_test.shape}")
print("")
print("테스트 데이터")
X_train_n = X_train_n_clipped.reshape(-1, 28, 28)
X_test_n = X_test_n_clipped.reshape(-1, 28, 28)
print(f"3차원 변환 전: {X_train_n_clipped.shape}, 후: {X_train.shape}")
print(f"3차원 변환 전: {X_test_n_clipped.shape}, 후: {X_test.shape}")

# CNN 파라미터: 노이즈 데이터를 주입할 것이기 때문에 노이즈로!!
n_height = X_train_n.shape[1] # 28
n_width = X_train_n.shape[2]
n_channel = 1 # 흑백 이미지

# 오토인코더 레이어 구성
x_Input = Input(batch_shape=(None, n_height, n_width, n_channel))

# 인코더
e_conv = Conv2D(filters=10, kernel_size=(3, 3), strides=1, padding='SAME', activation='relu')(x_Input) # same: 28*28
e_pool = MaxPooling2D(pool_size=(2,2), strides=1, padding='SAME')(e_conv) # same! 28 x 28

# 디코더
# d_conv = Conv2DTranspose(filters=10, kernel_size=(3, 3), strides=1, padding='SAME', activation='relu')(e_pool) # 아마 same이니까 28*28
x_Output = Conv2D(filters=1, kernel_size=(3, 3), strides=1, padding='SAME', activation='linear')(e_pool) 

# 모델 구성
model = Model(x_Input, x_Output)
model.compile(loss='mse', optimizer=Adam(lr=0.005)) # 이거 그냥 전에 sigmoid여서?
print("====== 모델 전체 구조 =====")
print(model.summary())

# 4차원에 맞추기 위해 채널 축 추가
X_train_n = X_train_n[:, :, :, np.newaxis]

# 오토인코더 학습: X_train과 X_train_n을 맞춘다.
hist = model.fit(X_train_n, X_train, epochs=100, batch_size=300, shuffle=True)

# plot loss
plt.plot(hist.history['loss'], label='Train Loss')
plt.title('Loss Trajectory')
plt.legend()
plt.show()

# 화면에 이미지 그림
def showImage(x):
    n = 0
    for k in range(2): # figure 2개에 10개 나눠 그림 그리기 위해 range(2)
        plt.figure(figsize=(8, 2))
        for i in range(5):
            ax = plt.subplot(1, 5, i+1)
            plt.imshow(x[n].reshape(28, 28))
            plt.gray()
            ax.get_xaxis().set_visible(False)
            ax.get_yaxis().set_visible(False)
            n += 1
        plt.show()

# 노이즈가 추가된 데이터 10개
print("잡음이 삽입된 테스트 데이터 10개")
showImage(X_test_n)

# 오토인코더 모델에 통과시켜서 잡음 제거
print(f"원래 테스트 데이터: {X_test_n.shape}")
X_test_n = X_test_n.reshape(-1, 28, 28)
X_test_n = X_test_n[:, :, :, np.newaxis] # 채널 축 추가
print(f"모델에 넣기 위해 차원을 변경한 데이터: {X_test_n.shape}")

# 잡음 제거
X_test_detected = model.predict(X_test_n)
plt.imshow(X_test_n[0].reshape(28, 28))
plt.show()
plt.imshow(X_test_detected[0].reshape(28, 28))
plt.show()

# 잡음을 제거한 테스트 데이터 10개
print("잡음을 제거한 테스트 데이터 10개")
showImage(X_test_detected)
# Out:
# 노이즈 삽입 전: (3000, 784), 노이즈 삽입 후: (3000, 784)
# 훈련 데이터
# 3차원 변환 후: (3000, 28, 28)
# 3차원 변환 후: (100, 28, 28)
#
# 테스트 데이터
# 3차원 변환 전: (3000, 784), 후: (3000, 28, 28)
# 3차원 변환 전: (100, 784), 후: (100, 28, 28)
# ====== 모델 전체 구조 =====
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 10)        100
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 28, 28, 10)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 1)         91
# =================================================================
# Total params: 191
# Trainable params: 191
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1214
# Epoch 2/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0577
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0363
# Epoch 4/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0251
# Epoch 5/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0203
# Epoch 6/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0192
# Epoch 7/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0182
# Epoch 8/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0175
# Epoch 9/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0167
# Epoch 10/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0160
# Epoch 11/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0153
# Epoch 12/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0147
# Epoch 13/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0140
# Epoch 14/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0135
# Epoch 15/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0131
# Epoch 16/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0128
# Epoch 17/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0125
# Epoch 18/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0123
# Epoch 19/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0121
# Epoch 20/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0118
# Epoch 21/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0116
# Epoch 22/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0114
# Epoch 23/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0113
# Epoch 24/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0111
# Epoch 25/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0109
# Epoch 26/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0108
# Epoch 27/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0106
# Epoch 28/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0105
# Epoch 29/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0104
# Epoch 30/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0103
# Epoch 31/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0103
# Epoch 32/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0102
# Epoch 33/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0101
# Epoch 34/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0100
# Epoch 35/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0100
# Epoch 36/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0099
# Epoch 37/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0099
# Epoch 38/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0098
# Epoch 39/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0098
# Epoch 40/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0097
# Epoch 41/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0097
# Epoch 42/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0097
# Epoch 43/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0096
# Epoch 44/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0096
# Epoch 45/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0096
# Epoch 46/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0095
# Epoch 47/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0095
# Epoch 48/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0095
# Epoch 49/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0094
# Epoch 50/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0094
# Epoch 51/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0094
# Epoch 52/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0094
# Epoch 53/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0094
# Epoch 54/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0093
# Epoch 55/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0093
# Epoch 56/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0093
# Epoch 57/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0093
# Epoch 58/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0093
# Epoch 59/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0092
# Epoch 60/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0092
# Epoch 61/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0092
# Epoch 62/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0092
# Epoch 63/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0092
# Epoch 64/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0092
# Epoch 65/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0092
# Epoch 66/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0091
# Epoch 67/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0091
# Epoch 68/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0091
# Epoch 69/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0091
# Epoch 70/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0091
# Epoch 71/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0091
# Epoch 72/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0091
# Epoch 73/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0090
# Epoch 74/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0090
# Epoch 75/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0090
# Epoch 76/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0090
# Epoch 77/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0090
# Epoch 78/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0090
# Epoch 79/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0090
# Epoch 80/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0089
# Epoch 81/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0089
# Epoch 82/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0089
# Epoch 83/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0089
# Epoch 84/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0089
# Epoch 85/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0089
# Epoch 86/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0089
# Epoch 87/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0089
# Epoch 88/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0088
# Epoch 89/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0088
# Epoch 90/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0088
# Epoch 91/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0088
# Epoch 92/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0088
# Epoch 93/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0088
# Epoch 94/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0088
# Epoch 95/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0088
# Epoch 96/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0087
# Epoch 97/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0087
# Epoch 98/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0087
# Epoch 99/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0087
# Epoch 100/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0087
# 잡음이 삽입된 테스트 데이터 10개
# 원래 테스트 데이터: (100, 28, 28)
# 모델에 넣기 위해 차원을 변경한 데이터: (100, 28, 28, 1)
# 잡음을 제거한 테스트 데이터 10개

# %%
# 데이터 가져 오기
mnist = data

# 입력 데이터 생성
X_train = mnist.data[:3000, :] / 255
X_test = mnist.data[3000:3100, :] / 255
plt.imshow(X_train[102].reshape(28, 28), cmap=plt.cm.bone)
plt.show()

# 노이즈 삽입
X_train_n = X_train + 0.3*np.random.normal(size=X_train.shape)
X_test_n = X_test + 0.3*np.random.normal(size=X_test.shape)
print(f"노이즈 삽입 전: {X_train.shape}, 노이즈 삽입 후: {X_train_n.shape}")

# 확인
plt.imshow(X_train_n[102].reshape(28, 28), cmap=plt.cm.bone)
plt.show()

# clip
X_train_n_clipped = np.clip(X_train_n, 0., 1.)
X_test_n_clipped = np.clip(X_test_n, 0., 1.)

# CNN에 주입하기 위해 차원 증가
print("훈련 데이터")
X_train = X_train.reshape(-1, 28, 28)
X_test = X_test.reshape(-1, 28, 28)
print(f"3차원 변환 후: {X_train.shape}")
print(f"3차원 변환 후: {X_test.shape}")
print("")
print("테스트 데이터")
X_train_n = X_train_n_clipped.reshape(-1, 28, 28)
X_test_n = X_test_n_clipped.reshape(-1, 28, 28)
print(f"3차원 변환 전: {X_train_n_clipped.shape}, 후: {X_train.shape}")
print(f"3차원 변환 전: {X_test_n_clipped.shape}, 후: {X_test.shape}")

# CNN 파라미터: 노이즈 데이터를 주입할 것이기 때문에 노이즈로!!
n_height = X_train_n.shape[1] # 28
n_width = X_train_n.shape[2]
n_channel = 1 # 흑백 이미지

# 오토인코더 레이어 구성
x_Input = Input(batch_shape=(None, n_height, n_width, n_channel))

# 인코더
e_conv = Conv2D(filters=10, kernel_size=(3, 3), strides=1, padding='SAME', activation='relu')(x_Input) # same: 28*28
# e_pool = MaxPooling2D(pool_size=(2,2), strides=1, padding='SAME')(e_conv) # same! 28 x 28

# 디코더
# d_conv = Conv2DTranspose(filters=10, kernel_size=(3, 3), strides=1, padding='SAME', activation='relu')(e_pool) # 아마 same이니까 28*28
x_Output = Conv2D(filters=1, kernel_size=(3, 3), strides=1, padding='SAME', activation='linear')(e_conv) 

# 모델 구성
model = Model(x_Input, x_Output)
model.compile(loss='mse', optimizer=Adam(lr=0.005)) # 이거 그냥 전에 sigmoid여서?
print("====== 모델 전체 구조 =====")
print(model.summary())

# 4차원에 맞추기 위해 채널 축 추가
X_train_n = X_train_n[:, :, :, np.newaxis]

# 오토인코더 학습: X_train과 X_train_n을 맞춘다.
hist = model.fit(X_train_n, X_train, epochs=100, batch_size=300, shuffle=True)

# plot loss
plt.plot(hist.history['loss'], label='Train Loss')
plt.title('Loss Trajectory')
plt.legend()
plt.show()

# 화면에 이미지 그림
def showImage(x):
    n = 0
    for k in range(2): # figure 2개에 10개 나눠 그림 그리기 위해 range(2)
        plt.figure(figsize=(8, 2))
        for i in range(5):
            ax = plt.subplot(1, 5, i+1)
            plt.imshow(x[n].reshape(28, 28))
            plt.gray()
            ax.get_xaxis().set_visible(False)
            ax.get_yaxis().set_visible(False)
            n += 1
        plt.show()

# 노이즈가 추가된 데이터 10개
print("잡음이 삽입된 테스트 데이터 10개")
showImage(X_test_n)

# 오토인코더 모델에 통과시켜서 잡음 제거
print(f"원래 테스트 데이터: {X_test_n.shape}")
X_test_n = X_test_n.reshape(-1, 28, 28)
X_test_n = X_test_n[:, :, :, np.newaxis] # 채널 축 추가
print(f"모델에 넣기 위해 차원을 변경한 데이터: {X_test_n.shape}")

# 잡음 제거
X_test_detected = model.predict(X_test_n)
plt.imshow(X_test_n[0].reshape(28, 28))
plt.show()
plt.imshow(X_test_detected[0].reshape(28, 28))
plt.show()

# 잡음을 제거한 테스트 데이터 10개
print("잡음을 제거한 테스트 데이터 10개")
showImage(X_test_detected)
# Out:
# 노이즈 삽입 전: (3000, 784), 노이즈 삽입 후: (3000, 784)
# 훈련 데이터
# 3차원 변환 후: (3000, 28, 28)
# 3차원 변환 후: (100, 28, 28)
#
# 테스트 데이터
# 3차원 변환 전: (3000, 784), 후: (3000, 28, 28)
# 3차원 변환 전: (100, 784), 후: (100, 28, 28)
# ====== 모델 전체 구조 =====
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 10)        100
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 28, 28, 1)         91
# =================================================================
# Total params: 191
# Trainable params: 191
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0618
# Epoch 2/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0280
# Epoch 3/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0164
# Epoch 4/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 5/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0122
# Epoch 6/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0112
# Epoch 7/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0105
# Epoch 8/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0101
# Epoch 9/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0097
# Epoch 10/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0094
# Epoch 11/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0091
# Epoch 12/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0090
# Epoch 13/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0088
# Epoch 14/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0087
# Epoch 15/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0087
# Epoch 16/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0086
# Epoch 17/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0085
# Epoch 18/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0085
# Epoch 19/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0084
# Epoch 20/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0084
# Epoch 21/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0083
# Epoch 22/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0083
# Epoch 23/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0082
# Epoch 24/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0082
# Epoch 25/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0082
# Epoch 26/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0081
# Epoch 27/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0081
# Epoch 28/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0080
# Epoch 29/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0080
# Epoch 30/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0079
# Epoch 31/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0079
# Epoch 32/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 33/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0077
# Epoch 34/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0077
# Epoch 35/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0076
# Epoch 36/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0076
# Epoch 37/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0075
# Epoch 38/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0074
# Epoch 39/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0074
# Epoch 40/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0073
# Epoch 41/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0072
# Epoch 42/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0072
# Epoch 43/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0071
# Epoch 44/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0070
# Epoch 45/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0069
# Epoch 46/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0069
# Epoch 47/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0068
# Epoch 48/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0068
# Epoch 49/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0067
# Epoch 50/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0067
# Epoch 51/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0066
# Epoch 52/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0066
# Epoch 53/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0065
# Epoch 54/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0065
# Epoch 55/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0064
# Epoch 56/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0064
# Epoch 57/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0064
# Epoch 58/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0063
# Epoch 59/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0063
# Epoch 60/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0063
# Epoch 61/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0063
# Epoch 62/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0063
# Epoch 63/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0062
# Epoch 64/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0062
# Epoch 65/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0062
# Epoch 66/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0062
# Epoch 67/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0062
# Epoch 68/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0062
# Epoch 69/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 70/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 71/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 72/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 73/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 74/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 75/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 76/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 77/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 78/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 79/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 80/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 81/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0060
# Epoch 82/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0060
# Epoch 83/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0060
# Epoch 84/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0060
# Epoch 85/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0060
# Epoch 86/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0060
# Epoch 87/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0060
# Epoch 88/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0060
# Epoch 89/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0060
# Epoch 90/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0060
# Epoch 91/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0060
# Epoch 92/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0060
# Epoch 93/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0060
# Epoch 94/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0061
# Epoch 95/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0060
# Epoch 96/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0060
# Epoch 97/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0060
# Epoch 98/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0060
# Epoch 99/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0060
# Epoch 100/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0060
# 잡음이 삽입된 테스트 데이터 10개
# 원래 테스트 데이터: (100, 28, 28)
# 모델에 넣기 위해 차원을 변경한 데이터: (100, 28, 28, 1)
# 잡음을 제거한 테스트 데이터 10개

# %%
# 데이터 가져 오기
mnist = data

# 입력 데이터 생성
X_train = mnist.data[:3000, :] / 255
X_test = mnist.data[3000:3100, :] / 255
plt.imshow(X_train[102].reshape(28, 28), cmap=plt.cm.bone)
plt.show()

# 노이즈 삽입
X_train_n = X_train + 0.3*np.random.normal(size=X_train.shape)
X_test_n = X_test + 0.3*np.random.normal(size=X_test.shape)
print(f"노이즈 삽입 전: {X_train.shape}, 노이즈 삽입 후: {X_train_n.shape}")

# 확인
plt.imshow(X_train_n[102].reshape(28, 28), cmap=plt.cm.bone)
plt.show()

# clip
X_train_n_clipped = np.clip(X_train_n, 0., 1.)
X_test_n_clipped = np.clip(X_test_n, 0., 1.)

# CNN에 주입하기 위해 차원 증가
print("훈련 데이터")
X_train = X_train.reshape(-1, 28, 28)
X_test = X_test.reshape(-1, 28, 28)
print(f"3차원 변환 후: {X_train.shape}")
print(f"3차원 변환 후: {X_test.shape}")
print("")
print("테스트 데이터")
X_train_n = X_train_n_clipped.reshape(-1, 28, 28)
X_test_n = X_test_n_clipped.reshape(-1, 28, 28)
print(f"3차원 변환 전: {X_train_n_clipped.shape}, 후: {X_train.shape}")
print(f"3차원 변환 전: {X_test_n_clipped.shape}, 후: {X_test.shape}")

# CNN 파라미터: 노이즈 데이터를 주입할 것이기 때문에 노이즈로!!
n_height = X_train_n.shape[1] # 28
n_width = X_train_n.shape[2]
n_channel = 1 # 흑백 이미지

# 오토인코더 레이어 구성
x_Input = Input(batch_shape=(None, n_height, n_width, n_channel))

# 인코더
# e_conv = Conv2D(filters=10, kernel_size=(3, 3), strides=1, padding='SAME', activation='relu')(x_Input) # same: 28*28
# e_pool = MaxPooling2D(pool_size=(2,2), strides=1, padding='SAME')(e_conv) # same! 28 x 28

# 디코더
# d_conv = Conv2DTranspose(filters=10, kernel_size=(3, 3), strides=1, padding='SAME', activation='relu')(e_pool) # 아마 same이니까 28*28
x_Output = Conv2D(filters=1, kernel_size=(3, 3), strides=1, padding='SAME', activation='linear')(x_Input) 

# 모델 구성
model = Model(x_Input, x_Output)
model.compile(loss='mse', optimizer=Adam(lr=0.005)) # 이거 그냥 전에 sigmoid여서?
print("====== 모델 전체 구조 =====")
print(model.summary())

# 4차원에 맞추기 위해 채널 축 추가
X_train_n = X_train_n[:, :, :, np.newaxis]

# 오토인코더 학습: X_train과 X_train_n을 맞춘다.
hist = model.fit(X_train_n, X_train, epochs=100, batch_size=300, shuffle=True)

# plot loss
plt.plot(hist.history['loss'], label='Train Loss')
plt.title('Loss Trajectory')
plt.legend()
plt.show()

# 화면에 이미지 그림
def showImage(x):
    n = 0
    for k in range(2): # figure 2개에 10개 나눠 그림 그리기 위해 range(2)
        plt.figure(figsize=(8, 2))
        for i in range(5):
            ax = plt.subplot(1, 5, i+1)
            plt.imshow(x[n].reshape(28, 28))
            plt.gray()
            ax.get_xaxis().set_visible(False)
            ax.get_yaxis().set_visible(False)
            n += 1
        plt.show()

# 노이즈가 추가된 데이터 10개
print("잡음이 삽입된 테스트 데이터 10개")
showImage(X_test_n)

# 오토인코더 모델에 통과시켜서 잡음 제거
print(f"원래 테스트 데이터: {X_test_n.shape}")
X_test_n = X_test_n.reshape(-1, 28, 28)
X_test_n = X_test_n[:, :, :, np.newaxis] # 채널 축 추가
print(f"모델에 넣기 위해 차원을 변경한 데이터: {X_test_n.shape}")

# 잡음 제거
X_test_detected = model.predict(X_test_n)
plt.imshow(X_test_n[0].reshape(28, 28))
plt.show()
plt.imshow(X_test_detected[0].reshape(28, 28))
plt.show()

# 잡음을 제거한 테스트 데이터 10개
print("잡음을 제거한 테스트 데이터 10개")
showImage(X_test_detected)
# Out:
# 노이즈 삽입 전: (3000, 784), 노이즈 삽입 후: (3000, 784)
# 훈련 데이터
# 3차원 변환 후: (3000, 28, 28)
# 3차원 변환 후: (100, 28, 28)
#
# 테스트 데이터
# 3차원 변환 전: (3000, 784), 후: (3000, 28, 28)
# 3차원 변환 전: (100, 784), 후: (100, 28, 28)
# ====== 모델 전체 구조 =====
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 28, 28, 1)         10
# =================================================================
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3066
# Epoch 2/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1872
# Epoch 3/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1266
# Epoch 4/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1029
# Epoch 5/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0918
# Epoch 6/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0816
# Epoch 7/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0719
# Epoch 8/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0635
# Epoch 9/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0565
# Epoch 10/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0505
# Epoch 11/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0455
# Epoch 12/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0412
# Epoch 13/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0377
# Epoch 14/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0346
# Epoch 15/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0321
# Epoch 16/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0300
# Epoch 17/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0281
# Epoch 18/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0266
# Epoch 19/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0252
# Epoch 20/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0241
# Epoch 21/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0230
# Epoch 22/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0221
# Epoch 23/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0213
# Epoch 24/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0206
# Epoch 25/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0200
# Epoch 26/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0194
# Epoch 27/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0189
# Epoch 28/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0185
# Epoch 29/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0181
# Epoch 30/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0177
# Epoch 31/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0174
# Epoch 32/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0171
# Epoch 33/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0169
# Epoch 34/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0167
# Epoch 35/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0165
# Epoch 36/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0163
# Epoch 37/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0161
# Epoch 38/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0160
# Epoch 39/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0158
# Epoch 40/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0157
# Epoch 41/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0156
# Epoch 42/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0155
# Epoch 43/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0155
# Epoch 44/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0154
# Epoch 45/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0153
# Epoch 46/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0153
# Epoch 47/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0153
# Epoch 48/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0152
# Epoch 49/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0152
# Epoch 50/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0152
# Epoch 51/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0151
# Epoch 52/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0151
# Epoch 53/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0151
# Epoch 54/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0151
# Epoch 55/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0151
# Epoch 56/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 57/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 58/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 59/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 60/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 61/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 62/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 63/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 64/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 65/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 66/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 67/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 68/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 69/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 70/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 71/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 72/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 73/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 74/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 75/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 76/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 77/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 78/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 79/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 80/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 81/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 82/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 83/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 84/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 85/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 86/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 87/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 88/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 89/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 90/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 91/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0150
# Epoch 92/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 93/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 94/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 95/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 96/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 97/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 98/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 99/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# Epoch 100/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0150
# 잡음이 삽입된 테스트 데이터 10개
# 원래 테스트 데이터: (100, 28, 28)
# 모델에 넣기 위해 차원을 변경한 데이터: (100, 28, 28, 1)
# 잡음을 제거한 테스트 데이터 10개
